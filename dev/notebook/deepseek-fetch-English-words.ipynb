# %%
import requests
import json
from time import time, sleep 
from openai import OpenAI 
import os
from dotenv import load_dotenv
import pandas as pd 
from pathlib import Path 
# Load environment variables from .env file
load_dotenv()

# Replace with your actual DeepSeek API endpoint and API key
DEEPSEEK_API_URL = "https://api.deepseek.com"
DEEPSEEK_API_KEY = os.getenv('DEEPSEEK_API_KEY')

OUT_FOLDER = "deepseek_enu"

# %%
json_data = """
{
  "core_function_words": {
    "articles": ["a", "an", "the"],
    "prepositions": ["of", "in", "to", "for", "with", "on", "at", "from", "by", "about", "as", "into", "like", "through", "after", "over", "between", "out", "against", "during", "without", "before", "under", "around", "among", "off", "above", "near", "behind", "below", "across", "along", "beside", "towards", "onto", "until"],
    "conjunctions": ["and", "but", "or", "nor", "so", "yet", "for", "although", "because", "if", "that", "while", "since", "unless", "whereas", "whether"],
    "pronouns": ["I", "you", "he", "she", "it", "we", "they", "me", "him", "her", "us", "them", "my", "your", "his", "her", "its", "our", "their", "mine", "yours", "hers", "ours", "theirs", "myself", "yourself", "himself", "herself", "itself", "ourselves", "yourselves", "themselves", "who", "whom", "whose", "which", "what", "this", "that", "these", "those", "each", "every", "some", "any", "no", "none", "all", "both", "either", "neither", "one", "another", "other", "such"],
    "auxiliary_verbs": ["be", "am", "is", "are", "was", "were", "been", "have", "has", "had", "do", "does", "did", "can", "could", "may", "might", "must", "shall", "should", "will", "would"]
  },
  "common_nouns": {
    "people": ["person", "man", "woman", "child", "boy", "girl", "family", "friend", "name", "group", "student", "teacher", "doctor", "president", "people", "father", "mother", "son", "daughter", "brother", "sister", "husband", "wife", "parent", "customer", "patient", "member", "worker", "leader"],
    "time": ["time", "year", "day", "week", "month", "hour", "minute", "second", "morning", "afternoon", "evening", "night", "today", "yesterday", "tomorrow", "moment", "period", "date", "age", "future", "past"],
    "place": ["place", "world", "country", "city", "state", "school", "home", "house", "room", "office", "area", "side", "street", "town", "area", "building", "land", "community", "region", "location"],
    "things": ["thing", "way", "part", "number", "word", "life", "point", "line", "form", "case", "system", "program", "question", "government", "company", "money", "water", "food", "car", "door", "book", "paper", "window", "table", "chair", "computer", "phone", "end", "law", "war", "power", "problem", "service", "idea", "reason", "level", "kind", "example", "result", "change", "process", "information", "head", "body", "hand", "eye", "face", "back", "side", "air", "fire", "ground"],
    "abstract_concepts": ["work", "fact", "issue", "effect", "use", "need", "type", "method", "research", "study", "experience", "development", "history", "art", "health", "job", "action", "activity", "decision", "value", "theory", "nature", "order", "course", "report", "education", "knowledge", "love", "relationship", "control", "force", "mind", "game", "quality", "situation", "society", "technology", "project", "plan", "rate", "cost", "event", "business"]
  },
  "common_verbs": {
    "basic_actions": ["be", "have", "do", "make", "get", "go", "come", "see", "look", "hear", "listen", "say", "tell", "talk", "speak", "take", "give", "find", "use", "work", "help", "start", "play", "run", "move", "live", "believe", "bring", "happen", "write", "sit", "stand", "lose", "meet", "include", "continue", "set", "learn", "change", "lead", "understand", "watch", "follow", "stop", "create", "allow", "add", "spend", "grow", "open", "walk", "win", "offer", "remember", "love", "consider", "appear", "buy", "serve", "die", "send", "expect", "build", "stay", "fall", "cut", "reach", "kill", "remain", "suggest", "raise", "pass", "sell", "require", "report", "decide", "pull", "return", "explain", "hope", "develop", "carry", "thank", "receive", "join", "agree", "hit", "produce", "eat", "cover", "catch", "choose", "deal", "throw", "keep", "hold"],
    "mental_actions": ["think", "know", "want", "need", "mean", "feel", "become", "seem", "try", "call", "ask", "show", "seem", "care", "worry", "expect", "imagine", "wonder"],
    "communication": ["speak", "talk", "say", "tell", "ask", "answer", "call", "write", "read", "communicate", "explain", "describe", "report", "inform"],
    "change_influence": ["become", "change", "make", "do", "create", "build", "form", "develop", "increase", "decrease", "improve", "reduce", "affect", "cause", "impact", "influence"],
    "relationships": ["meet", "know", "love", "like", "help", "support", "join", "leave", "follow", "lead"],
    "existence_state": ["be", "exist", "live", "stay", "remain", "seem", "appear", "happen"]
  },
  "common_adjectives": {
    "basic_qualities": ["good", "new", "old", "great", "high", "low", "small", "large", "big", "little", "long", "short", "strong", "weak", "right", "wrong", "different", "important", "possible", "real", "best", "better", "easy", "difficult", "hard", "true", "false", "clear", "simple", "special", "certain", "personal", "open", "public", "common", "full", "available", "ready", "nice", "fine"],
    "descriptive": ["red", "blue", "green", "black", "white", "dark", "light", "beautiful", "happy", "sad", "bad", "serious", "free", "able", "sure", "likely", "single", "recent", "early", "late", "main", "major", "particular", "similar", "significant", "difficult", "easy", "human", "local", "national", "international", "social", "political", "economic", "financial", "legal", "medical", "environmental", "physical", "mental", "general", "specific"],
    "evaluative": ["important", "necessary", "useful", "valuable", "effective", "successful", "popular", "interesting", "positive", "negative", "same", "similar", "different"],
    "quantity_degree": ["much", "many", "few", "several", "enough", "whole", "total", "entire", "half", "most", "least"]
  },
  "common_adverbs": {
    "manner": ["well", "quickly", "slowly", "carefully", "easily", "really", "actually", "probably", "very", "also", "just", "then", "now", "here", "there", "up", "down", "away", "back", "forward", "together", "alone", "early", "late", "again", "still", "always", "never", "often", "sometimes", "usually", "ever", "almost", "already", "even", "only", "quite", "too", "enough", "however", "therefore", "finally", "recently", "especially", "particularly", "generally", "completely", "totally", "absolutely", "simply"],
    "time": ["now", "then", "today", "yesterday", "tomorrow", "soon", "later", "ago", "before", "after", "always", "usually", "often", "sometimes", "rarely", "never", "already", "still", "yet"],
    "place": ["here", "there", "somewhere", "anywhere", "everywhere", "nowhere", "inside", "outside", "above", "below", "near", "far", "away"],
    "degree": ["very", "quite", "rather", "pretty", "really", "extremely", "incredibly", "fairly", "somewhat", "hardly", "barely", "slightly"],
    "frequency": ["always", "usually", "often", "frequently", "sometimes", "occasionally", "seldom", "rarely", "never"]
  },
  "numbers": ["one", "two", "three", "four", "five", "six", "seven", "eight", "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen", "sixteen", "seventeen", "eighteen", "nineteen", "twenty", "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety", "hundred", "thousand", "million", "billion", "first", "second", "third", "fourth", "fifth", "last"],
  "question_words": ["who", "what", "where", "when", "why", "how", "which", "whose", "whom"]
}
"""

# %% [raw]
# # test
# json_data = """
# {
#   "core_function_words": {
#     "pronouns": ["I", "you"]
#   }
# }
# """

# %%
parsed_json = json.loads(json_data)

# %% [raw]
# parsed_json

# %%
words = []
for category in parsed_json.keys():
    sub_cat = parsed_json[category]
    if isinstance(sub_cat,dict):
        for subcategory in parsed_json[category].keys():
            words += sub_cat[subcategory]        
    elif isinstance(sub_cat,list):
        words += sub_cat

print(f"Total number of words in the JSON: {len(words)}")
# Out:
# Total number of words in the JSON: 714

# %% [raw]
# words

# %%
deepseek_client = OpenAI(api_key=DEEPSEEK_API_KEY, base_url=DEEPSEEK_API_URL)

# %% [raw]
# def generate_custom_prompt(character):
#     """
#     Generates a custom prompt for the DeepSeek API based on your template.
#
#     Args:
#         character (str): The Chinese character to query.
#
#     Returns:
#         str: A formatted prompt for the API.
#     """
#     prompt = f"""
#     You are an expert in Chinese language.
#     Generate a holistic view on the Chinese character '{character}'
#     in terms of the following attributes:
#
#     1. 含义 (meaning): Explain its meaning.
#     2. 字形 (character structure): Describe its structure.
#     3. 读音 (pronunciation): Provide its pronunciation.
#     4. 字源 (etymology): Explain its origin.
#     5. 含此字的字 (composite characters): List characters that contain '{character}'.
#     6. 同音字 (homophone characters): List other characters that sound like '{character}'.
#     7. 常用词组 (common phrases): Provide common phrases containing '{character}' (often 2-characters).
#     8. 成语 (idioms): List idioms containing '{character}' (often 4-characters).
#     9. 例句 (example sentences): Provide example short sentences or famous quotes using '{character}'.
#     10. 短故事 (short stories): Share 1-2 short stories related to '{character}'.
#     11. 诗词 (poetry): Include 1-2 famous poems containing and describing '{character}'.
#     12. 图片 (images): Suggest simple images illustrating '{character}'.
#     13. 音频 (audio): Suggest short audio clips illustrating '{character}'.
#     14. 视频 (video): Suggest short video clips illustrating '{character}'.
#     15. 电影 (movies): List famous movies related to '{character}' or movie titles containing '{character}'.
#     16. 参考资料 (references): Provide additional popular reference materials.
#     17. 有趣网站 (interesting websites): Suggest popular websites related to '{character}'.
#
#     Format the output as a valid JSON object.
#     """
#     return prompt.strip()

# %%
def generate_enu_prompt(word, category="", subcategory=""):
    """
    Generates a custom prompt for the DeepSeek API based on your template.

    Args:
        character (str): The Chinese character to query.

    Returns:
        str: A formatted prompt for the API.
    """
    if category:
        cat_prompt = f" which belongs to '{category}' category "
        if subcategory:
            cat_prompt += f" and '{subcategory}' sub-category"
    else:
        cat_prompt = "" 
    prompt = f"""
    You are an expert in English language. 
    Generate a wholistic view in terms of the following attributes 
    on this word '{word}' {cat_prompt} :

    - meaning: Explain its meaning.
    - pronunciation: Provide its pronunciation.
    - etymology: Explain its origin.
    - homophone word: List other words that sound like '{word}'.
    - common phrase: Provide common phrases containing '{word}' 
    - sentence: Provide example short sentences or famous quotes using '{word}'.
    - short stories: Share 1-2 short stories related to '{word}'.
    - poetry: Include 1-2 famous poems containing and describing '{word}'.
    - image: Suggest simple images illustrating '{word}'.
    - audio: Suggest short audio clips illustrating '{word}'.
    - video: Suggest short video clips illustrating '{word}'.
    - movie: List famous movies related to '{word}' or movie titles containing '{word}'.
    - reference: Provide additional popular reference materials.
    - interesting website: Suggest popular websites related to '{word}'.

    Format the output as a valid JSON object.
    """
    return prompt.strip()

# %%
generate_enu_prompt("human", category="biology", subcategory="")
# Out:
# "You are an expert in English language. \n    Generate a wholistic view in terms of the following attributes \n    on this word 'human'  which belongs to 'biology' category  :\n\n    - meaning: Explain its meaning.\n    - pronunciation: Provide its pronunciation.\n    - etymology: Explain its origin.\n    - homophone word: List other words that sound like 'human'.\n    - common phrase: Provide common phrases containing 'human' \n    - sentence: Provide example short sentences or famous quotes using 'human'.\n    - short stories: Share 1-2 short stories related to 'human'.\n    - poetry: Include 1-2 famous poems containing and describing 'human'.\n    - image: Suggest simple images illustrating 'human'.\n    - audio: Suggest short audio clips illustrating 'human'.\n    - video: Suggest short video clips illustrating 'human'.\n    - movie: List famous movies related to 'human' or movie titles containing 'human'.\n    - reference: Provide additional popular reference materials.\n    - interesting website: Suggest popular websites related to 'human'.\n\n    Format the output as a valid JSON object."

# %%
def extract_json_string(response):
    # Find the start and end of the JSON string
    start = response.find("```json") + len("```json")
    end = response.find("```", start)

    # Extract the JSON string and strip any leading/trailing whitespace
    json_str = response[start:end].strip()

    return json_str

# %%
def call_deepseek_api(prompt, system_message = "You are a helpful assistant", client=None):
    if client is None:
        client = OpenAI(api_key=DEEPSEEK_API_KEY, base_url=DEEPSEEK_API_URL)
    ts_start = time()
    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": prompt},
        ],
        stream=False
    )
    ts_stop = time()

    return response.choices[0].message.content, (ts_stop-ts_start)

# %%
def main(character="son", category="", subcategory="", out_folder=OUT_FOLDER):
    # Call the DeepSeek API
    prompt = generate_enu_prompt(character, category, subcategory)

    response, ts_delta = call_deepseek_api(prompt, client=deepseek_client)
    json_str = extract_json_string(response)
    json_obj = json.loads(json_str)
    json_out = json.dumps(json_obj, indent=2, ensure_ascii=False)
    file_json = f"{out_folder}/{character}-1.json"
    print(f"API call for '{character}' completed in {ts_delta} sec, \n output written to {file_json}")
    with open(file_json, "w", encoding="utf-8") as f:
        f.write(json_out)

# %%
def process_words(words, cat="", sub_cat="", out_folder=OUT_FOLDER):
    processed = []
    for zi in words:
        file_json = f"{out_folder}/{zi}-1.json"
        if Path(file_json).exists():
            print(f"Skip {zi}")
            continue
        try:
            main(character = zi, category=cat, subcategory=sub_cat)
            processed.append(zi)
        except Exception as e: 
            print(f"Failed to process {zi}:\n {str(e)}")    
    return processed

# %%
processed = []

for category in parsed_json.keys():
    sub_cat = parsed_json[category]
    if isinstance(sub_cat,dict):
        for subcategory in parsed_json[category].keys():
            words = sub_cat[subcategory]
            processed += process_words(words, cat=category, sub_cat=subcategory)
    elif isinstance(sub_cat,list):
        words = sub_cat
        processed += process_words(words, cat=category)
# Out:
# API call for 'a' completed in 17.480198621749878 sec,
#  output written to deepseek_enu/a-1.json
# API call for 'an' completed in 13.252955198287964 sec,
#  output written to deepseek_enu/an-1.json
# API call for 'the' completed in 16.925647974014282 sec,
#  output written to deepseek_enu/the-1.json
# API call for 'of' completed in 18.194700956344604 sec,
#  output written to deepseek_enu/of-1.json
# API call for 'in' completed in 15.008503198623657 sec,
#  output written to deepseek_enu/in-1.json
# API call for 'to' completed in 14.622117519378662 sec,
#  output written to deepseek_enu/to-1.json
# API call for 'for' completed in 18.098021745681763 sec,
#  output written to deepseek_enu/for-1.json
# API call for 'with' completed in 16.942495346069336 sec,
#  output written to deepseek_enu/with-1.json
# API call for 'on' completed in 13.444606304168701 sec,
#  output written to deepseek_enu/on-1.json
# API call for 'at' completed in 16.19912362098694 sec,
#  output written to deepseek_enu/at-1.json
# API call for 'from' completed in 16.702742338180542 sec,
#  output written to deepseek_enu/from-1.json
# API call for 'by' completed in 15.848307609558105 sec,
#  output written to deepseek_enu/by-1.json
# API call for 'about' completed in 20.10417604446411 sec,
#  output written to deepseek_enu/about-1.json
# API call for 'as' completed in 19.776159048080444 sec,
#  output written to deepseek_enu/as-1.json
# API call for 'into' completed in 15.859533071517944 sec,
#  output written to deepseek_enu/into-1.json
# API call for 'like' completed in 16.429558515548706 sec,
#  output written to deepseek_enu/like-1.json
# API call for 'through' completed in 15.22326946258545 sec,
#  output written to deepseek_enu/through-1.json
# API call for 'after' completed in 17.648648500442505 sec,
#  output written to deepseek_enu/after-1.json
# API call for 'over' completed in 14.855741024017334 sec,
#  output written to deepseek_enu/over-1.json
# API call for 'between' completed in 18.445536613464355 sec,
#  output written to deepseek_enu/between-1.json
# API call for 'out' completed in 17.40720772743225 sec,
#  output written to deepseek_enu/out-1.json
# API call for 'against' completed in 14.648037910461426 sec,
#  output written to deepseek_enu/against-1.json
# API call for 'during' completed in 17.183167457580566 sec,
#  output written to deepseek_enu/during-1.json
# API call for 'without' completed in 15.68086862564087 sec,
#  output written to deepseek_enu/without-1.json
# API call for 'before' completed in 16.22042942047119 sec,
#  output written to deepseek_enu/before-1.json
# API call for 'under' completed in 18.649184465408325 sec,
#  output written to deepseek_enu/under-1.json
# API call for 'around' completed in 14.861568450927734 sec,
#  output written to deepseek_enu/around-1.json
# API call for 'among' completed in 17.3692889213562 sec,
#  output written to deepseek_enu/among-1.json
# API call for 'off' completed in 16.11980366706848 sec,
#  output written to deepseek_enu/off-1.json
# API call for 'above' completed in 17.16124391555786 sec,
#  output written to deepseek_enu/above-1.json
# API call for 'near' completed in 16.590015411376953 sec,
#  output written to deepseek_enu/near-1.json
# API call for 'behind' completed in 18.75390362739563 sec,
#  output written to deepseek_enu/behind-1.json
# API call for 'below' completed in 16.86145544052124 sec,
#  output written to deepseek_enu/below-1.json
# API call for 'across' completed in 16.654113054275513 sec,
#  output written to deepseek_enu/across-1.json
# API call for 'along' completed in 12.679990530014038 sec,
#  output written to deepseek_enu/along-1.json
# API call for 'beside' completed in 14.098078727722168 sec,
#  output written to deepseek_enu/beside-1.json
# API call for 'towards' completed in 18.679571628570557 sec,
#  output written to deepseek_enu/towards-1.json
# API call for 'onto' completed in 14.59071660041809 sec,
#  output written to deepseek_enu/onto-1.json
# API call for 'until' completed in 17.334084033966064 sec,
#  output written to deepseek_enu/until-1.json
# API call for 'and' completed in 15.952691793441772 sec,
#  output written to deepseek_enu/and-1.json
# API call for 'but' completed in 17.60940408706665 sec,
#  output written to deepseek_enu/but-1.json
# API call for 'or' completed in 15.520703554153442 sec,
#  output written to deepseek_enu/or-1.json
# API call for 'nor' completed in 17.4501850605011 sec,
#  output written to deepseek_enu/nor-1.json
# API call for 'so' completed in 23.19776463508606 sec,
#  output written to deepseek_enu/so-1.json
# API call for 'yet' completed in 18.25831890106201 sec,
#  output written to deepseek_enu/yet-1.json
# Skip for
# API call for 'although' completed in 15.795591115951538 sec,
#  output written to deepseek_enu/although-1.json
# API call for 'because' completed in 19.49202799797058 sec,
#  output written to deepseek_enu/because-1.json
# API call for 'if' completed in 22.203855752944946 sec,
#  output written to deepseek_enu/if-1.json
# API call for 'that' completed in 17.118114471435547 sec,
#  output written to deepseek_enu/that-1.json
# API call for 'while' completed in 16.42730951309204 sec,
#  output written to deepseek_enu/while-1.json
# API call for 'since' completed in 17.076408863067627 sec,
#  output written to deepseek_enu/since-1.json
# API call for 'unless' completed in 18.005717754364014 sec,
#  output written to deepseek_enu/unless-1.json
# API call for 'whereas' completed in 17.308783769607544 sec,
#  output written to deepseek_enu/whereas-1.json
# API call for 'whether' completed in 19.551014184951782 sec,
#  output written to deepseek_enu/whether-1.json
# Skip I
# Skip you
# API call for 'he' completed in 16.064953804016113 sec,
#  output written to deepseek_enu/he-1.json
# API call for 'she' completed in 17.95555567741394 sec,
#  output written to deepseek_enu/she-1.json
# API call for 'it' completed in 15.629044532775879 sec,
#  output written to deepseek_enu/it-1.json
# API call for 'we' completed in 15.397628545761108 sec,
#  output written to deepseek_enu/we-1.json
# Failed to process they:
#  Invalid \escape: line 17 column 62 (char 1497)
# API call for 'me' completed in 14.171618938446045 sec,
#  output written to deepseek_enu/me-1.json
# API call for 'him' completed in 16.37133502960205 sec,
#  output written to deepseek_enu/him-1.json
# API call for 'her' completed in 17.057120084762573 sec,
#  output written to deepseek_enu/her-1.json
# API call for 'us' completed in 17.38305950164795 sec,
#  output written to deepseek_enu/us-1.json
# API call for 'them' completed in 20.56939697265625 sec,
#  output written to deepseek_enu/them-1.json
# API call for 'my' completed in 17.960917949676514 sec,
#  output written to deepseek_enu/my-1.json
# API call for 'your' completed in 16.330693006515503 sec,
#  output written to deepseek_enu/your-1.json
# API call for 'his' completed in 17.43635392189026 sec,
#  output written to deepseek_enu/his-1.json
# Skip her
# API call for 'its' completed in 13.271738052368164 sec,
#  output written to deepseek_enu/its-1.json
# API call for 'our' completed in 16.237488508224487 sec,
#  output written to deepseek_enu/our-1.json
# API call for 'their' completed in 17.5579674243927 sec,
#  output written to deepseek_enu/their-1.json
# API call for 'mine' completed in 16.30077886581421 sec,
#  output written to deepseek_enu/mine-1.json
# API call for 'yours' completed in 20.902865171432495 sec,
#  output written to deepseek_enu/yours-1.json
# API call for 'hers' completed in 15.56901216506958 sec,
#  output written to deepseek_enu/hers-1.json
# API call for 'ours' completed in 17.459789752960205 sec,
#  output written to deepseek_enu/ours-1.json
# API call for 'theirs' completed in 15.834707021713257 sec,
#  output written to deepseek_enu/theirs-1.json
# API call for 'myself' completed in 16.651063442230225 sec,
#  output written to deepseek_enu/myself-1.json
# API call for 'yourself' completed in 17.114957332611084 sec,
#  output written to deepseek_enu/yourself-1.json
# API call for 'himself' completed in 16.218830823898315 sec,
#  output written to deepseek_enu/himself-1.json
# API call for 'herself' completed in 14.868952751159668 sec,
#  output written to deepseek_enu/herself-1.json
# API call for 'itself' completed in 18.168627500534058 sec,
#  output written to deepseek_enu/itself-1.json
# API call for 'ourselves' completed in 16.836905241012573 sec,
#  output written to deepseek_enu/ourselves-1.json
# API call for 'yourselves' completed in 17.276864767074585 sec,
#  output written to deepseek_enu/yourselves-1.json
# API call for 'themselves' completed in 16.21254563331604 sec,
#  output written to deepseek_enu/themselves-1.json
# API call for 'who' completed in 15.362658500671387 sec,
#  output written to deepseek_enu/who-1.json
# API call for 'whom' completed in 16.165207624435425 sec,
#  output written to deepseek_enu/whom-1.json
# API call for 'whose' completed in 15.246801137924194 sec,
#  output written to deepseek_enu/whose-1.json
# API call for 'which' completed in 19.332354307174683 sec,
#  output written to deepseek_enu/which-1.json
# API call for 'what' completed in 13.859436988830566 sec,
#  output written to deepseek_enu/what-1.json
# API call for 'this' completed in 16.821837186813354 sec,
#  output written to deepseek_enu/this-1.json
# Skip that
# API call for 'these' completed in 15.178189992904663 sec,
#  output written to deepseek_enu/these-1.json
# API call for 'those' completed in 15.076056957244873 sec,
#  output written to deepseek_enu/those-1.json
# API call for 'each' completed in 13.90178918838501 sec,
#  output written to deepseek_enu/each-1.json
# API call for 'every' completed in 11.900063753128052 sec,
#  output written to deepseek_enu/every-1.json
# API call for 'some' completed in 17.266655445098877 sec,
#  output written to deepseek_enu/some-1.json
# API call for 'any' completed in 14.231704235076904 sec,
#  output written to deepseek_enu/any-1.json
# API call for 'no' completed in 16.5143723487854 sec,
#  output written to deepseek_enu/no-1.json
# API call for 'none' completed in 15.063685178756714 sec,
#  output written to deepseek_enu/none-1.json
# API call for 'all' completed in 16.480865240097046 sec,
#  output written to deepseek_enu/all-1.json
# API call for 'both' completed in 17.846814155578613 sec,
#  output written to deepseek_enu/both-1.json
# API call for 'either' completed in 14.912902116775513 sec,
#  output written to deepseek_enu/either-1.json
# API call for 'neither' completed in 18.66297197341919 sec,
#  output written to deepseek_enu/neither-1.json
# API call for 'one' completed in 14.368664503097534 sec,
#  output written to deepseek_enu/one-1.json
# API call for 'another' completed in 12.972057819366455 sec,
#  output written to deepseek_enu/another-1.json
# API call for 'other' completed in 16.748238801956177 sec,
#  output written to deepseek_enu/other-1.json
# API call for 'such' completed in 16.571399450302124 sec,
#  output written to deepseek_enu/such-1.json
# API call for 'be' completed in 18.28838300704956 sec,
#  output written to deepseek_enu/be-1.json
# API call for 'am' completed in 13.092172145843506 sec,
#  output written to deepseek_enu/am-1.json
# API call for 'is' completed in 13.784334659576416 sec,
#  output written to deepseek_enu/is-1.json
# API call for 'are' completed in 12.711254119873047 sec,
#  output written to deepseek_enu/are-1.json
# API call for 'was' completed in 17.953580856323242 sec,
#  output written to deepseek_enu/was-1.json
# API call for 'were' completed in 14.05431842803955 sec,
#  output written to deepseek_enu/were-1.json
# API call for 'been' completed in 15.554441213607788 sec,
#  output written to deepseek_enu/been-1.json
# API call for 'have' completed in 15.428313732147217 sec,
#  output written to deepseek_enu/have-1.json
# API call for 'has' completed in 24.737704277038574 sec,
#  output written to deepseek_enu/has-1.json
# API call for 'had' completed in 14.054689645767212 sec,
#  output written to deepseek_enu/had-1.json
# API call for 'do' completed in 17.193167686462402 sec,
#  output written to deepseek_enu/do-1.json
# API call for 'does' completed in 18.312411308288574 sec,
#  output written to deepseek_enu/does-1.json
# API call for 'did' completed in 15.959571838378906 sec,
#  output written to deepseek_enu/did-1.json
# API call for 'can' completed in 18.554932594299316 sec,
#  output written to deepseek_enu/can-1.json
# API call for 'could' completed in 17.46954607963562 sec,
#  output written to deepseek_enu/could-1.json
# API call for 'may' completed in 18.22919988632202 sec,
#  output written to deepseek_enu/may-1.json
# API call for 'might' completed in 14.904059886932373 sec,
#  output written to deepseek_enu/might-1.json
# API call for 'must' completed in 16.564226627349854 sec,
#  output written to deepseek_enu/must-1.json
# API call for 'shall' completed in 16.651875972747803 sec,
#  output written to deepseek_enu/shall-1.json
# API call for 'should' completed in 19.643328189849854 sec,
#  output written to deepseek_enu/should-1.json
# API call for 'will' completed in 19.40210223197937 sec,
#  output written to deepseek_enu/will-1.json
# API call for 'would' completed in 19.341526985168457 sec,
#  output written to deepseek_enu/would-1.json
# API call for 'person' completed in 14.981467485427856 sec,
#  output written to deepseek_enu/person-1.json
# API call for 'man' completed in 15.200254678726196 sec,
#  output written to deepseek_enu/man-1.json
# API call for 'woman' completed in 17.67420482635498 sec,
#  output written to deepseek_enu/woman-1.json
# API call for 'child' completed in 14.8084135055542 sec,
#  output written to deepseek_enu/child-1.json
# API call for 'boy' completed in 17.911206483840942 sec,
#  output written to deepseek_enu/boy-1.json
# API call for 'girl' completed in 17.199819087982178 sec,
#  output written to deepseek_enu/girl-1.json
# API call for 'family' completed in 14.872205018997192 sec,
#  output written to deepseek_enu/family-1.json
# API call for 'friend' completed in 14.073314189910889 sec,
#  output written to deepseek_enu/friend-1.json
# API call for 'name' completed in 18.282029628753662 sec,
#  output written to deepseek_enu/name-1.json
# API call for 'group' completed in 14.92646312713623 sec,
#  output written to deepseek_enu/group-1.json
# API call for 'student' completed in 15.98416805267334 sec,
#  output written to deepseek_enu/student-1.json
# API call for 'teacher' completed in 17.365909814834595 sec,
#  output written to deepseek_enu/teacher-1.json
# API call for 'doctor' completed in 12.667338609695435 sec,
#  output written to deepseek_enu/doctor-1.json
# API call for 'president' completed in 15.075702667236328 sec,
#  output written to deepseek_enu/president-1.json
# API call for 'people' completed in 14.0778489112854 sec,
#  output written to deepseek_enu/people-1.json
# API call for 'father' completed in 14.688156366348267 sec,
#  output written to deepseek_enu/father-1.json
# API call for 'mother' completed in 16.304687976837158 sec,
#  output written to deepseek_enu/mother-1.json
# API call for 'son' completed in 15.30583143234253 sec,
#  output written to deepseek_enu/son-1.json
# API call for 'daughter' completed in 14.327230453491211 sec,
#  output written to deepseek_enu/daughter-1.json
# API call for 'brother' completed in 15.218610525131226 sec,
#  output written to deepseek_enu/brother-1.json
# API call for 'sister' completed in 15.209665060043335 sec,
#  output written to deepseek_enu/sister-1.json
# API call for 'husband' completed in 17.252503156661987 sec,
#  output written to deepseek_enu/husband-1.json
# API call for 'wife' completed in 17.86889410018921 sec,
#  output written to deepseek_enu/wife-1.json
# API call for 'parent' completed in 18.71421504020691 sec,
#  output written to deepseek_enu/parent-1.json
# API call for 'customer' completed in 17.19626784324646 sec,
#  output written to deepseek_enu/customer-1.json
# API call for 'patient' completed in 15.506246089935303 sec,
#  output written to deepseek_enu/patient-1.json
# API call for 'member' completed in 16.902462482452393 sec,
#  output written to deepseek_enu/member-1.json
# API call for 'worker' completed in 19.09584093093872 sec,
#  output written to deepseek_enu/worker-1.json
# API call for 'leader' completed in 25.030304193496704 sec,
#  output written to deepseek_enu/leader-1.json
# API call for 'time' completed in 15.025582790374756 sec,
#  output written to deepseek_enu/time-1.json
# API call for 'year' completed in 15.903613328933716 sec,
#  output written to deepseek_enu/year-1.json
# API call for 'day' completed in 17.891056537628174 sec,
#  output written to deepseek_enu/day-1.json
# API call for 'week' completed in 15.522216320037842 sec,
#  output written to deepseek_enu/week-1.json
# API call for 'month' completed in 13.746701955795288 sec,
#  output written to deepseek_enu/month-1.json
# API call for 'hour' completed in 19.199199676513672 sec,
#  output written to deepseek_enu/hour-1.json
# API call for 'minute' completed in 15.302237510681152 sec,
#  output written to deepseek_enu/minute-1.json
# API call for 'second' completed in 15.061413764953613 sec,
#  output written to deepseek_enu/second-1.json
# API call for 'morning' completed in 18.82902956008911 sec,
#  output written to deepseek_enu/morning-1.json
# API call for 'afternoon' completed in 18.64539623260498 sec,
#  output written to deepseek_enu/afternoon-1.json
# API call for 'evening' completed in 18.37855100631714 sec,
#  output written to deepseek_enu/evening-1.json
# API call for 'night' completed in 13.152798891067505 sec,
#  output written to deepseek_enu/night-1.json
# API call for 'today' completed in 18.6242618560791 sec,
#  output written to deepseek_enu/today-1.json
# API call for 'yesterday' completed in 17.53290629386902 sec,
#  output written to deepseek_enu/yesterday-1.json
# API call for 'tomorrow' completed in 14.607687711715698 sec,
#  output written to deepseek_enu/tomorrow-1.json
# API call for 'moment' completed in 13.545243740081787 sec,
#  output written to deepseek_enu/moment-1.json
# API call for 'period' completed in 19.316328763961792 sec,
#  output written to deepseek_enu/period-1.json
# API call for 'date' completed in 13.664918422698975 sec,
#  output written to deepseek_enu/date-1.json
# API call for 'age' completed in 16.164640188217163 sec,
#  output written to deepseek_enu/age-1.json
# API call for 'future' completed in 16.717350721359253 sec,
#  output written to deepseek_enu/future-1.json
# API call for 'past' completed in 17.536166667938232 sec,
#  output written to deepseek_enu/past-1.json
# API call for 'place' completed in 17.036155223846436 sec,
#  output written to deepseek_enu/place-1.json
# API call for 'world' completed in 15.021671295166016 sec,
#  output written to deepseek_enu/world-1.json
# API call for 'country' completed in 16.97899317741394 sec,
#  output written to deepseek_enu/country-1.json
# API call for 'city' completed in 21.553162813186646 sec,
#  output written to deepseek_enu/city-1.json
# API call for 'state' completed in 14.102193593978882 sec,
#  output written to deepseek_enu/state-1.json
# API call for 'school' completed in 15.16541337966919 sec,
#  output written to deepseek_enu/school-1.json
# API call for 'home' completed in 17.388773202896118 sec,
#  output written to deepseek_enu/home-1.json
# API call for 'house' completed in 21.233094215393066 sec,
#  output written to deepseek_enu/house-1.json
# API call for 'room' completed in 17.040496349334717 sec,
#  output written to deepseek_enu/room-1.json
# API call for 'office' completed in 19.85863161087036 sec,
#  output written to deepseek_enu/office-1.json
# API call for 'area' completed in 14.786088943481445 sec,
#  output written to deepseek_enu/area-1.json
# API call for 'side' completed in 18.686661958694458 sec,
#  output written to deepseek_enu/side-1.json
# API call for 'street' completed in 15.91485857963562 sec,
#  output written to deepseek_enu/street-1.json
# API call for 'town' completed in 18.25308060646057 sec,
#  output written to deepseek_enu/town-1.json
# Skip area
# API call for 'building' completed in 15.396247148513794 sec,
#  output written to deepseek_enu/building-1.json
# API call for 'land' completed in 14.489717483520508 sec,
#  output written to deepseek_enu/land-1.json
# API call for 'community' completed in 14.159912347793579 sec,
#  output written to deepseek_enu/community-1.json
# API call for 'region' completed in 17.735180854797363 sec,
#  output written to deepseek_enu/region-1.json
# API call for 'location' completed in 17.141895294189453 sec,
#  output written to deepseek_enu/location-1.json
# API call for 'thing' completed in 18.874688148498535 sec,
#  output written to deepseek_enu/thing-1.json
# API call for 'way' completed in 18.779132843017578 sec,
#  output written to deepseek_enu/way-1.json
# API call for 'part' completed in 15.628530502319336 sec,
#  output written to deepseek_enu/part-1.json
# API call for 'number' completed in 16.18028688430786 sec,
#  output written to deepseek_enu/number-1.json
# API call for 'word' completed in 13.921550035476685 sec,
#  output written to deepseek_enu/word-1.json
# API call for 'life' completed in 21.31124973297119 sec,
#  output written to deepseek_enu/life-1.json
# API call for 'point' completed in 16.327491760253906 sec,
#  output written to deepseek_enu/point-1.json
# API call for 'line' completed in 14.934051275253296 sec,
#  output written to deepseek_enu/line-1.json
# API call for 'form' completed in 13.102089643478394 sec,
#  output written to deepseek_enu/form-1.json
# API call for 'case' completed in 15.375071048736572 sec,
#  output written to deepseek_enu/case-1.json
# API call for 'system' completed in 16.630730628967285 sec,
#  output written to deepseek_enu/system-1.json
# API call for 'program' completed in 14.533786296844482 sec,
#  output written to deepseek_enu/program-1.json
# API call for 'question' completed in 19.366203546524048 sec,
#  output written to deepseek_enu/question-1.json
# API call for 'government' completed in 15.702369689941406 sec,
#  output written to deepseek_enu/government-1.json
# API call for 'company' completed in 17.61168885231018 sec,
#  output written to deepseek_enu/company-1.json
# API call for 'money' completed in 14.822148084640503 sec,
#  output written to deepseek_enu/money-1.json
# API call for 'water' completed in 15.759546518325806 sec,
#  output written to deepseek_enu/water-1.json
# API call for 'food' completed in 17.55510377883911 sec,
#  output written to deepseek_enu/food-1.json
# API call for 'car' completed in 19.32461643218994 sec,
#  output written to deepseek_enu/car-1.json
# API call for 'door' completed in 17.19801115989685 sec,
#  output written to deepseek_enu/door-1.json
# API call for 'book' completed in 16.24860715866089 sec,
#  output written to deepseek_enu/book-1.json
# API call for 'paper' completed in 15.244992971420288 sec,
#  output written to deepseek_enu/paper-1.json
# API call for 'window' completed in 16.411998510360718 sec,
#  output written to deepseek_enu/window-1.json
# API call for 'table' completed in 17.835582733154297 sec,
#  output written to deepseek_enu/table-1.json
# API call for 'chair' completed in 17.64284873008728 sec,
#  output written to deepseek_enu/chair-1.json
# API call for 'computer' completed in 17.06170916557312 sec,
#  output written to deepseek_enu/computer-1.json
# API call for 'phone' completed in 17.83939242362976 sec,
#  output written to deepseek_enu/phone-1.json
# API call for 'end' completed in 14.459836483001709 sec,
#  output written to deepseek_enu/end-1.json
# API call for 'law' completed in 14.070739269256592 sec,
#  output written to deepseek_enu/law-1.json
# API call for 'war' completed in 15.983282089233398 sec,
#  output written to deepseek_enu/war-1.json
# API call for 'power' completed in 17.83981990814209 sec,
#  output written to deepseek_enu/power-1.json
# Failed to process problem:
#  Expecting ',' delimiter: line 34 column 26 (char 2091)
# API call for 'service' completed in 13.750160694122314 sec,
#  output written to deepseek_enu/service-1.json
# API call for 'idea' completed in 20.831597328186035 sec,
#  output written to deepseek_enu/idea-1.json
# API call for 'reason' completed in 20.420084953308105 sec,
#  output written to deepseek_enu/reason-1.json
# API call for 'level' completed in 16.431009531021118 sec,
#  output written to deepseek_enu/level-1.json
# API call for 'kind' completed in 18.99827527999878 sec,
#  output written to deepseek_enu/kind-1.json
# API call for 'example' completed in 16.698429584503174 sec,
#  output written to deepseek_enu/example-1.json
# API call for 'result' completed in 16.197833776474 sec,
#  output written to deepseek_enu/result-1.json
# API call for 'change' completed in 16.64772605895996 sec,
#  output written to deepseek_enu/change-1.json
# API call for 'process' completed in 17.36587429046631 sec,
#  output written to deepseek_enu/process-1.json
# API call for 'information' completed in 20.72648549079895 sec,
#  output written to deepseek_enu/information-1.json
# API call for 'head' completed in 18.154454231262207 sec,
#  output written to deepseek_enu/head-1.json
# API call for 'body' completed in 21.173779726028442 sec,
#  output written to deepseek_enu/body-1.json
# API call for 'hand' completed in 22.771055936813354 sec,
#  output written to deepseek_enu/hand-1.json
# API call for 'eye' completed in 16.170180320739746 sec,
#  output written to deepseek_enu/eye-1.json
# API call for 'face' completed in 13.843894481658936 sec,
#  output written to deepseek_enu/face-1.json
# API call for 'back' completed in 16.66243863105774 sec,
#  output written to deepseek_enu/back-1.json
# Skip side
# API call for 'air' completed in 18.099297523498535 sec,
#  output written to deepseek_enu/air-1.json
# API call for 'fire' completed in 18.06807827949524 sec,
#  output written to deepseek_enu/fire-1.json
# API call for 'ground' completed in 16.567718744277954 sec,
#  output written to deepseek_enu/ground-1.json
# API call for 'work' completed in 25.007866382598877 sec,
#  output written to deepseek_enu/work-1.json
# API call for 'fact' completed in 17.458003044128418 sec,
#  output written to deepseek_enu/fact-1.json
# API call for 'issue' completed in 16.6334011554718 sec,
#  output written to deepseek_enu/issue-1.json
# API call for 'effect' completed in 17.565098762512207 sec,
#  output written to deepseek_enu/effect-1.json
# API call for 'use' completed in 18.754396438598633 sec,
#  output written to deepseek_enu/use-1.json
# API call for 'need' completed in 22.17613434791565 sec,
#  output written to deepseek_enu/need-1.json
# API call for 'type' completed in 16.523751497268677 sec,
#  output written to deepseek_enu/type-1.json
# API call for 'method' completed in 14.909048557281494 sec,
#  output written to deepseek_enu/method-1.json
# API call for 'research' completed in 17.481754302978516 sec,
#  output written to deepseek_enu/research-1.json
# API call for 'study' completed in 20.835827589035034 sec,
#  output written to deepseek_enu/study-1.json
# API call for 'experience' completed in 16.88242197036743 sec,
#  output written to deepseek_enu/experience-1.json
# API call for 'development' completed in 17.3451931476593 sec,
#  output written to deepseek_enu/development-1.json
# API call for 'history' completed in 16.214778661727905 sec,
#  output written to deepseek_enu/history-1.json
# API call for 'art' completed in 17.165085077285767 sec,
#  output written to deepseek_enu/art-1.json
# API call for 'health' completed in 16.148845672607422 sec,
#  output written to deepseek_enu/health-1.json
# API call for 'job' completed in 18.537797212600708 sec,
#  output written to deepseek_enu/job-1.json
# API call for 'action' completed in 15.55901026725769 sec,
#  output written to deepseek_enu/action-1.json
# API call for 'activity' completed in 22.82845401763916 sec,
#  output written to deepseek_enu/activity-1.json
# API call for 'decision' completed in 16.30827260017395 sec,
#  output written to deepseek_enu/decision-1.json
# API call for 'value' completed in 16.504352569580078 sec,
#  output written to deepseek_enu/value-1.json
# API call for 'theory' completed in 16.475874423980713 sec,
#  output written to deepseek_enu/theory-1.json
# API call for 'nature' completed in 15.830792427062988 sec,
#  output written to deepseek_enu/nature-1.json
# API call for 'order' completed in 17.029572010040283 sec,
#  output written to deepseek_enu/order-1.json
# API call for 'course' completed in 17.12898874282837 sec,
#  output written to deepseek_enu/course-1.json
# API call for 'report' completed in 17.067059755325317 sec,
#  output written to deepseek_enu/report-1.json
# API call for 'education' completed in 15.79739499092102 sec,
#  output written to deepseek_enu/education-1.json
# API call for 'knowledge' completed in 19.793845415115356 sec,
#  output written to deepseek_enu/knowledge-1.json
# API call for 'love' completed in 15.843369245529175 sec,
#  output written to deepseek_enu/love-1.json
# API call for 'relationship' completed in 16.614266633987427 sec,
#  output written to deepseek_enu/relationship-1.json
# API call for 'control' completed in 16.12497043609619 sec,
#  output written to deepseek_enu/control-1.json
# API call for 'force' completed in 14.225431203842163 sec,
#  output written to deepseek_enu/force-1.json
# API call for 'mind' completed in 18.621244430541992 sec,
#  output written to deepseek_enu/mind-1.json
# API call for 'game' completed in 17.895939588546753 sec,
#  output written to deepseek_enu/game-1.json
# API call for 'quality' completed in 14.540518522262573 sec,
#  output written to deepseek_enu/quality-1.json
# API call for 'situation' completed in 18.837549209594727 sec,
#  output written to deepseek_enu/situation-1.json
# API call for 'society' completed in 15.205580234527588 sec,
#  output written to deepseek_enu/society-1.json
# API call for 'technology' completed in 18.14077854156494 sec,
#  output written to deepseek_enu/technology-1.json
# API call for 'project' completed in 16.13894534111023 sec,
#  output written to deepseek_enu/project-1.json
# API call for 'plan' completed in 14.42909049987793 sec,
#  output written to deepseek_enu/plan-1.json
# API call for 'rate' completed in 14.385379314422607 sec,
#  output written to deepseek_enu/rate-1.json
# API call for 'cost' completed in 17.584326028823853 sec,
#  output written to deepseek_enu/cost-1.json
# API call for 'event' completed in 19.030719757080078 sec,
#  output written to deepseek_enu/event-1.json
# API call for 'business' completed in 18.31796431541443 sec,
#  output written to deepseek_enu/business-1.json
# Skip be
# Skip have
# Skip do
# API call for 'make' completed in 17.32395052909851 sec,
#  output written to deepseek_enu/make-1.json
# API call for 'get' completed in 22.275036096572876 sec,
#  output written to deepseek_enu/get-1.json
# API call for 'go' completed in 21.433638334274292 sec,
#  output written to deepseek_enu/go-1.json
# API call for 'come' completed in 16.362180948257446 sec,
#  output written to deepseek_enu/come-1.json
# API call for 'see' completed in 17.134549617767334 sec,
#  output written to deepseek_enu/see-1.json
# API call for 'look' completed in 15.642151117324829 sec,
#  output written to deepseek_enu/look-1.json
# API call for 'hear' completed in 20.751720905303955 sec,
#  output written to deepseek_enu/hear-1.json
# API call for 'listen' completed in 14.506603240966797 sec,
#  output written to deepseek_enu/listen-1.json
# API call for 'say' completed in 17.055681705474854 sec,
#  output written to deepseek_enu/say-1.json
# API call for 'tell' completed in 18.013875722885132 sec,
#  output written to deepseek_enu/tell-1.json
# API call for 'talk' completed in 15.209003925323486 sec,
#  output written to deepseek_enu/talk-1.json
# API call for 'speak' completed in 14.74230146408081 sec,
#  output written to deepseek_enu/speak-1.json
# API call for 'take' completed in 16.13178539276123 sec,
#  output written to deepseek_enu/take-1.json
# API call for 'give' completed in 15.333855152130127 sec,
#  output written to deepseek_enu/give-1.json
# API call for 'find' completed in 14.634987831115723 sec,
#  output written to deepseek_enu/find-1.json
# Skip use
# Skip work
# API call for 'help' completed in 17.57815957069397 sec,
#  output written to deepseek_enu/help-1.json
# API call for 'start' completed in 18.459558486938477 sec,
#  output written to deepseek_enu/start-1.json
# Failed to process play:
#  Unterminated string starting at: line 27 column 5 (char 1546)
# API call for 'run' completed in 14.84762716293335 sec,
#  output written to deepseek_enu/run-1.json
# API call for 'move' completed in 16.133811235427856 sec,
#  output written to deepseek_enu/move-1.json
# API call for 'live' completed in 14.591164350509644 sec,
#  output written to deepseek_enu/live-1.json
# API call for 'believe' completed in 23.143125295639038 sec,
#  output written to deepseek_enu/believe-1.json
# API call for 'bring' completed in 16.48209023475647 sec,
#  output written to deepseek_enu/bring-1.json
# API call for 'happen' completed in 16.09394145011902 sec,
#  output written to deepseek_enu/happen-1.json
# API call for 'write' completed in 17.581770420074463 sec,
#  output written to deepseek_enu/write-1.json
# API call for 'sit' completed in 17.19736909866333 sec,
#  output written to deepseek_enu/sit-1.json
# API call for 'stand' completed in 15.192319631576538 sec,
#  output written to deepseek_enu/stand-1.json
# API call for 'lose' completed in 22.80908441543579 sec,
#  output written to deepseek_enu/lose-1.json
# API call for 'meet' completed in 15.400699377059937 sec,
#  output written to deepseek_enu/meet-1.json
# API call for 'include' completed in 17.43864345550537 sec,
#  output written to deepseek_enu/include-1.json
# API call for 'continue' completed in 14.172811508178711 sec,
#  output written to deepseek_enu/continue-1.json
# API call for 'set' completed in 20.29839515686035 sec,
#  output written to deepseek_enu/set-1.json
# API call for 'learn' completed in 16.114689588546753 sec,
#  output written to deepseek_enu/learn-1.json
# Skip change
# API call for 'lead' completed in 16.607683420181274 sec,
#  output written to deepseek_enu/lead-1.json
# API call for 'understand' completed in 15.307388544082642 sec,
#  output written to deepseek_enu/understand-1.json
# API call for 'watch' completed in 18.11398935317993 sec,
#  output written to deepseek_enu/watch-1.json
# API call for 'follow' completed in 15.637834310531616 sec,
#  output written to deepseek_enu/follow-1.json
# API call for 'stop' completed in 17.230590343475342 sec,
#  output written to deepseek_enu/stop-1.json
# API call for 'create' completed in 13.824470520019531 sec,
#  output written to deepseek_enu/create-1.json
# API call for 'allow' completed in 17.452147960662842 sec,
#  output written to deepseek_enu/allow-1.json
# API call for 'add' completed in 15.076919555664062 sec,
#  output written to deepseek_enu/add-1.json
# API call for 'spend' completed in 20.17865800857544 sec,
#  output written to deepseek_enu/spend-1.json
# API call for 'grow' completed in 18.46674871444702 sec,
#  output written to deepseek_enu/grow-1.json
# API call for 'open' completed in 19.942296981811523 sec,
#  output written to deepseek_enu/open-1.json
# API call for 'walk' completed in 14.309011459350586 sec,
#  output written to deepseek_enu/walk-1.json
# API call for 'win' completed in 19.76988911628723 sec,
#  output written to deepseek_enu/win-1.json
# API call for 'offer' completed in 17.86693286895752 sec,
#  output written to deepseek_enu/offer-1.json
# API call for 'remember' completed in 19.830952882766724 sec,
#  output written to deepseek_enu/remember-1.json
# Skip love
# API call for 'consider' completed in 19.324517965316772 sec,
#  output written to deepseek_enu/consider-1.json
# API call for 'appear' completed in 19.929280042648315 sec,
#  output written to deepseek_enu/appear-1.json
# API call for 'buy' completed in 20.1293625831604 sec,
#  output written to deepseek_enu/buy-1.json
# API call for 'serve' completed in 14.549731016159058 sec,
#  output written to deepseek_enu/serve-1.json
# API call for 'die' completed in 14.883813381195068 sec,
#  output written to deepseek_enu/die-1.json
# API call for 'send' completed in 18.546963214874268 sec,
#  output written to deepseek_enu/send-1.json
# API call for 'expect' completed in 14.388913631439209 sec,
#  output written to deepseek_enu/expect-1.json
# API call for 'build' completed in 17.190053462982178 sec,
#  output written to deepseek_enu/build-1.json
# API call for 'stay' completed in 16.153998374938965 sec,
#  output written to deepseek_enu/stay-1.json
# API call for 'fall' completed in 16.514094352722168 sec,
#  output written to deepseek_enu/fall-1.json
# API call for 'cut' completed in 14.069212913513184 sec,
#  output written to deepseek_enu/cut-1.json
# API call for 'reach' completed in 19.374760150909424 sec,
#  output written to deepseek_enu/reach-1.json
# API call for 'kill' completed in 14.093432903289795 sec,
#  output written to deepseek_enu/kill-1.json
# API call for 'remain' completed in 17.85765266418457 sec,
#  output written to deepseek_enu/remain-1.json
# API call for 'suggest' completed in 16.685611724853516 sec,
#  output written to deepseek_enu/suggest-1.json
# API call for 'raise' completed in 17.761929512023926 sec,
#  output written to deepseek_enu/raise-1.json
# API call for 'pass' completed in 15.520641565322876 sec,
#  output written to deepseek_enu/pass-1.json
# API call for 'sell' completed in 16.05239510536194 sec,
#  output written to deepseek_enu/sell-1.json
# API call for 'require' completed in 17.203539609909058 sec,
#  output written to deepseek_enu/require-1.json
# Skip report
# API call for 'decide' completed in 15.896119832992554 sec,
#  output written to deepseek_enu/decide-1.json
# API call for 'pull' completed in 13.084819793701172 sec,
#  output written to deepseek_enu/pull-1.json
# API call for 'return' completed in 15.683050632476807 sec,
#  output written to deepseek_enu/return-1.json
# API call for 'explain' completed in 15.450663805007935 sec,
#  output written to deepseek_enu/explain-1.json
# API call for 'hope' completed in 20.541468858718872 sec,
#  output written to deepseek_enu/hope-1.json
# API call for 'develop' completed in 16.42368459701538 sec,
#  output written to deepseek_enu/develop-1.json
# API call for 'carry' completed in 17.774325370788574 sec,
#  output written to deepseek_enu/carry-1.json
# API call for 'thank' completed in 18.388357400894165 sec,
#  output written to deepseek_enu/thank-1.json
# API call for 'receive' completed in 16.855592966079712 sec,
#  output written to deepseek_enu/receive-1.json
# API call for 'join' completed in 15.593419313430786 sec,
#  output written to deepseek_enu/join-1.json
# API call for 'agree' completed in 12.606910467147827 sec,
#  output written to deepseek_enu/agree-1.json
# API call for 'hit' completed in 15.399349689483643 sec,
#  output written to deepseek_enu/hit-1.json
# API call for 'produce' completed in 17.720379114151 sec,
#  output written to deepseek_enu/produce-1.json
# API call for 'eat' completed in 13.86368441581726 sec,
#  output written to deepseek_enu/eat-1.json
# API call for 'cover' completed in 15.934033632278442 sec,
#  output written to deepseek_enu/cover-1.json
# API call for 'catch' completed in 16.561330556869507 sec,
#  output written to deepseek_enu/catch-1.json
# API call for 'choose' completed in 14.368170976638794 sec,
#  output written to deepseek_enu/choose-1.json
# API call for 'deal' completed in 19.183109998703003 sec,
#  output written to deepseek_enu/deal-1.json
# API call for 'throw' completed in 17.01714539527893 sec,
#  output written to deepseek_enu/throw-1.json
# API call for 'keep' completed in 14.810164213180542 sec,
#  output written to deepseek_enu/keep-1.json
# API call for 'hold' completed in 20.70685887336731 sec,
#  output written to deepseek_enu/hold-1.json
# API call for 'think' completed in 14.811823844909668 sec,
#  output written to deepseek_enu/think-1.json
# API call for 'know' completed in 20.213680505752563 sec,
#  output written to deepseek_enu/know-1.json
# API call for 'want' completed in 15.344883918762207 sec,
#  output written to deepseek_enu/want-1.json
# Skip need
# API call for 'mean' completed in 15.0683753490448 sec,
#  output written to deepseek_enu/mean-1.json
# API call for 'feel' completed in 18.732916355133057 sec,
#  output written to deepseek_enu/feel-1.json
# API call for 'become' completed in 19.96094059944153 sec,
#  output written to deepseek_enu/become-1.json
# API call for 'seem' completed in 17.102497577667236 sec,
#  output written to deepseek_enu/seem-1.json
# API call for 'try' completed in 17.63954758644104 sec,
#  output written to deepseek_enu/try-1.json
# API call for 'call' completed in 16.67704463005066 sec,
#  output written to deepseek_enu/call-1.json
# API call for 'ask' completed in 14.89269232749939 sec,
#  output written to deepseek_enu/ask-1.json
# API call for 'show' completed in 19.058444023132324 sec,
#  output written to deepseek_enu/show-1.json
# Skip seem
# API call for 'care' completed in 16.076934099197388 sec,
#  output written to deepseek_enu/care-1.json
# API call for 'worry' completed in 19.539164543151855 sec,
#  output written to deepseek_enu/worry-1.json
# Skip expect
# API call for 'imagine' completed in 14.109836101531982 sec,
#  output written to deepseek_enu/imagine-1.json
# API call for 'wonder' completed in 21.732070922851562 sec,
#  output written to deepseek_enu/wonder-1.json
# Skip speak
# Skip talk
# Skip say
# Skip tell
# Skip ask
# API call for 'answer' completed in 16.49253273010254 sec,
#  output written to deepseek_enu/answer-1.json
# Skip call
# Skip write
# API call for 'read' completed in 14.719881057739258 sec,
#  output written to deepseek_enu/read-1.json
# API call for 'communicate' completed in 16.61491107940674 sec,
#  output written to deepseek_enu/communicate-1.json
# Skip explain
# API call for 'describe' completed in 21.001694440841675 sec,
#  output written to deepseek_enu/describe-1.json
# Skip report
# API call for 'inform' completed in 13.397252798080444 sec,
#  output written to deepseek_enu/inform-1.json
# Skip become
# Skip change
# Skip make
# Skip do
# Skip create
# Skip build
# Skip form
# Skip develop
# API call for 'increase' completed in 17.193737745285034 sec,
#  output written to deepseek_enu/increase-1.json
# API call for 'decrease' completed in 16.08383274078369 sec,
#  output written to deepseek_enu/decrease-1.json
# API call for 'improve' completed in 20.612641096115112 sec,
#  output written to deepseek_enu/improve-1.json
# API call for 'reduce' completed in 17.00175905227661 sec,
#  output written to deepseek_enu/reduce-1.json
# API call for 'affect' completed in 15.473253965377808 sec,
#  output written to deepseek_enu/affect-1.json
# API call for 'cause' completed in 16.76030683517456 sec,
#  output written to deepseek_enu/cause-1.json
# API call for 'impact' completed in 18.95969271659851 sec,
#  output written to deepseek_enu/impact-1.json
# API call for 'influence' completed in 16.066906929016113 sec,
#  output written to deepseek_enu/influence-1.json
# Skip meet
# Skip know
# Skip love
# Skip like
# Skip help
# API call for 'support' completed in 16.645246505737305 sec,
#  output written to deepseek_enu/support-1.json
# Skip join
# API call for 'leave' completed in 21.32333517074585 sec,
#  output written to deepseek_enu/leave-1.json
# Skip follow
# Skip lead
# Skip be
# API call for 'exist' completed in 13.153880596160889 sec,
#  output written to deepseek_enu/exist-1.json
# Skip live
# Skip stay
# Skip remain
# Skip seem
# Skip appear
# Skip happen
# API call for 'good' completed in 18.114293813705444 sec,
#  output written to deepseek_enu/good-1.json
# API call for 'new' completed in 17.879703521728516 sec,
#  output written to deepseek_enu/new-1.json
# API call for 'old' completed in 19.492623567581177 sec,
#  output written to deepseek_enu/old-1.json
# API call for 'great' completed in 17.607579469680786 sec,
#  output written to deepseek_enu/great-1.json
# API call for 'high' completed in 16.356271505355835 sec,
#  output written to deepseek_enu/high-1.json
# API call for 'low' completed in 15.119624137878418 sec,
#  output written to deepseek_enu/low-1.json
# API call for 'small' completed in 15.5970938205719 sec,
#  output written to deepseek_enu/small-1.json
# API call for 'large' completed in 15.218423128128052 sec,
#  output written to deepseek_enu/large-1.json
# API call for 'big' completed in 15.99190640449524 sec,
#  output written to deepseek_enu/big-1.json
# API call for 'little' completed in 15.833287477493286 sec,
#  output written to deepseek_enu/little-1.json
# API call for 'long' completed in 13.984092235565186 sec,
#  output written to deepseek_enu/long-1.json
# API call for 'short' completed in 15.63400912284851 sec,
#  output written to deepseek_enu/short-1.json
# API call for 'strong' completed in 16.459096431732178 sec,
#  output written to deepseek_enu/strong-1.json
# API call for 'weak' completed in 17.04071545600891 sec,
#  output written to deepseek_enu/weak-1.json
# API call for 'right' completed in 18.011019706726074 sec,
#  output written to deepseek_enu/right-1.json
# API call for 'wrong' completed in 19.550764799118042 sec,
#  output written to deepseek_enu/wrong-1.json
# API call for 'different' completed in 16.74019193649292 sec,
#  output written to deepseek_enu/different-1.json
# API call for 'important' completed in 17.76760196685791 sec,
#  output written to deepseek_enu/important-1.json
# API call for 'possible' completed in 15.23871922492981 sec,
#  output written to deepseek_enu/possible-1.json
# API call for 'real' completed in 14.92889404296875 sec,
#  output written to deepseek_enu/real-1.json
# API call for 'best' completed in 16.301759719848633 sec,
#  output written to deepseek_enu/best-1.json
# API call for 'better' completed in 25.03575110435486 sec,
#  output written to deepseek_enu/better-1.json
# API call for 'easy' completed in 14.590280294418335 sec,
#  output written to deepseek_enu/easy-1.json
# API call for 'difficult' completed in 18.03972363471985 sec,
#  output written to deepseek_enu/difficult-1.json
# API call for 'hard' completed in 14.532751560211182 sec,
#  output written to deepseek_enu/hard-1.json
# API call for 'true' completed in 14.061413526535034 sec,
#  output written to deepseek_enu/true-1.json
# API call for 'false' completed in 16.885433673858643 sec,
#  output written to deepseek_enu/false-1.json
# API call for 'clear' completed in 14.96933126449585 sec,
#  output written to deepseek_enu/clear-1.json
# API call for 'simple' completed in 15.03444242477417 sec,
#  output written to deepseek_enu/simple-1.json
# API call for 'special' completed in 17.501447200775146 sec,
#  output written to deepseek_enu/special-1.json
# API call for 'certain' completed in 15.118195056915283 sec,
#  output written to deepseek_enu/certain-1.json
# API call for 'personal' completed in 13.646527767181396 sec,
#  output written to deepseek_enu/personal-1.json
# Skip open
# API call for 'public' completed in 13.550995826721191 sec,
#  output written to deepseek_enu/public-1.json
# API call for 'common' completed in 11.596483707427979 sec,
#  output written to deepseek_enu/common-1.json
# API call for 'full' completed in 17.584062099456787 sec,
#  output written to deepseek_enu/full-1.json
# API call for 'available' completed in 18.14658546447754 sec,
#  output written to deepseek_enu/available-1.json
# API call for 'ready' completed in 17.088799476623535 sec,
#  output written to deepseek_enu/ready-1.json
# API call for 'nice' completed in 14.585066080093384 sec,
#  output written to deepseek_enu/nice-1.json
# API call for 'fine' completed in 13.720615148544312 sec,
#  output written to deepseek_enu/fine-1.json
# API call for 'red' completed in 16.83987784385681 sec,
#  output written to deepseek_enu/red-1.json
# API call for 'blue' completed in 16.398452281951904 sec,
#  output written to deepseek_enu/blue-1.json
# API call for 'green' completed in 12.977335214614868 sec,
#  output written to deepseek_enu/green-1.json
# API call for 'black' completed in 17.940401792526245 sec,
#  output written to deepseek_enu/black-1.json
# API call for 'white' completed in 16.594873428344727 sec,
#  output written to deepseek_enu/white-1.json
# API call for 'dark' completed in 15.836974859237671 sec,
#  output written to deepseek_enu/dark-1.json
# API call for 'light' completed in 15.809189796447754 sec,
#  output written to deepseek_enu/light-1.json
# API call for 'beautiful' completed in 14.101751565933228 sec,
#  output written to deepseek_enu/beautiful-1.json
# API call for 'happy' completed in 14.742248058319092 sec,
#  output written to deepseek_enu/happy-1.json
# API call for 'sad' completed in 19.07075595855713 sec,
#  output written to deepseek_enu/sad-1.json
# ...
#  output written to deepseek_enu/significant-1.json
# Skip difficult
# Skip easy
# API call for 'human' completed in 13.545839071273804 sec,
#  output written to deepseek_enu/human-1.json
# API call for 'local' completed in 15.40318512916565 sec,
#  output written to deepseek_enu/local-1.json
# API call for 'national' completed in 14.417957782745361 sec,
#  output written to deepseek_enu/national-1.json
# API call for 'international' completed in 13.84869647026062 sec,
#  output written to deepseek_enu/international-1.json
# API call for 'social' completed in 16.253165006637573 sec,
#  output written to deepseek_enu/social-1.json
# API call for 'political' completed in 13.265098333358765 sec,
#  output written to deepseek_enu/political-1.json
# API call for 'economic' completed in 15.699310541152954 sec,
#  output written to deepseek_enu/economic-1.json
# API call for 'financial' completed in 15.089907169342041 sec,
#  output written to deepseek_enu/financial-1.json
# API call for 'legal' completed in 14.032010555267334 sec,
#  output written to deepseek_enu/legal-1.json
# API call for 'medical' completed in 13.647187948226929 sec,
#  output written to deepseek_enu/medical-1.json
# API call for 'environmental' completed in 16.515315532684326 sec,
#  output written to deepseek_enu/environmental-1.json
# API call for 'physical' completed in 14.031061172485352 sec,
#  output written to deepseek_enu/physical-1.json
# API call for 'mental' completed in 15.002480745315552 sec,
#  output written to deepseek_enu/mental-1.json
# API call for 'general' completed in 15.47654128074646 sec,
#  output written to deepseek_enu/general-1.json
# API call for 'specific' completed in 17.260026454925537 sec,
#  output written to deepseek_enu/specific-1.json
# Skip important
# API call for 'necessary' completed in 12.831690311431885 sec,
#  output written to deepseek_enu/necessary-1.json
# API call for 'useful' completed in 15.119382381439209 sec,
#  output written to deepseek_enu/useful-1.json
# API call for 'valuable' completed in 15.617241144180298 sec,
#  output written to deepseek_enu/valuable-1.json
# API call for 'effective' completed in 12.523381233215332 sec,
#  output written to deepseek_enu/effective-1.json
# API call for 'successful' completed in 19.22441053390503 sec,
#  output written to deepseek_enu/successful-1.json
# API call for 'popular' completed in 17.453938722610474 sec,
#  output written to deepseek_enu/popular-1.json
# API call for 'interesting' completed in 13.05503535270691 sec,
#  output written to deepseek_enu/interesting-1.json
# API call for 'positive' completed in 13.133379936218262 sec,
#  output written to deepseek_enu/positive-1.json
# API call for 'negative' completed in 16.078123331069946 sec,
#  output written to deepseek_enu/negative-1.json
# API call for 'same' completed in 15.076869010925293 sec,
#  output written to deepseek_enu/same-1.json
# Skip similar
# Skip different
# API call for 'much' completed in 14.291701316833496 sec,
#  output written to deepseek_enu/much-1.json
# API call for 'many' completed in 17.400771379470825 sec,
#  output written to deepseek_enu/many-1.json
# API call for 'few' completed in 17.164494037628174 sec,
#  output written to deepseek_enu/few-1.json
# API call for 'several' completed in 16.773162364959717 sec,
#  output written to deepseek_enu/several-1.json
# API call for 'enough' completed in 14.88383960723877 sec,
#  output written to deepseek_enu/enough-1.json
# API call for 'whole' completed in 13.945136308670044 sec,
#  output written to deepseek_enu/whole-1.json
# API call for 'total' completed in 14.701130628585815 sec,
#  output written to deepseek_enu/total-1.json
# API call for 'entire' completed in 19.66119956970215 sec,
#  output written to deepseek_enu/entire-1.json
# API call for 'half' completed in 15.065302848815918 sec,
#  output written to deepseek_enu/half-1.json
# API call for 'most' completed in 17.09209895133972 sec,
#  output written to deepseek_enu/most-1.json
# API call for 'least' completed in 16.7303683757782 sec,
#  output written to deepseek_enu/least-1.json
# API call for 'well' completed in 13.635036706924438 sec,
#  output written to deepseek_enu/well-1.json
# API call for 'quickly' completed in 13.821734428405762 sec,
#  output written to deepseek_enu/quickly-1.json
# API call for 'slowly' completed in 18.86603307723999 sec,
#  output written to deepseek_enu/slowly-1.json
# API call for 'carefully' completed in 19.333430528640747 sec,
#  output written to deepseek_enu/carefully-1.json
# API call for 'easily' completed in 17.948757648468018 sec,
#  output written to deepseek_enu/easily-1.json
# API call for 'really' completed in 15.055497646331787 sec,
#  output written to deepseek_enu/really-1.json
# API call for 'actually' completed in 12.329065561294556 sec,
#  output written to deepseek_enu/actually-1.json
# API call for 'probably' completed in 14.293331384658813 sec,
#  output written to deepseek_enu/probably-1.json
# API call for 'very' completed in 14.474349021911621 sec,
#  output written to deepseek_enu/very-1.json
# API call for 'also' completed in 18.403538703918457 sec,
#  output written to deepseek_enu/also-1.json
# API call for 'just' completed in 14.361767768859863 sec,
#  output written to deepseek_enu/just-1.json
# API call for 'then' completed in 17.0082745552063 sec,
#  output written to deepseek_enu/then-1.json
# API call for 'now' completed in 16.561500549316406 sec,
#  output written to deepseek_enu/now-1.json
# API call for 'here' completed in 16.076014757156372 sec,
#  output written to deepseek_enu/here-1.json
# API call for 'there' completed in 15.866483926773071 sec,
#  output written to deepseek_enu/there-1.json
# API call for 'up' completed in 14.367810010910034 sec,
#  output written to deepseek_enu/up-1.json
# API call for 'down' completed in 14.51293134689331 sec,
#  output written to deepseek_enu/down-1.json
# API call for 'away' completed in 14.316750288009644 sec,
#  output written to deepseek_enu/away-1.json
# Skip back
# API call for 'forward' completed in 12.620921611785889 sec,
#  output written to deepseek_enu/forward-1.json
# API call for 'together' completed in 16.697757244110107 sec,
#  output written to deepseek_enu/together-1.json
# API call for 'alone' completed in 14.16581392288208 sec,
#  output written to deepseek_enu/alone-1.json
# Skip early
# Skip late
# API call for 'again' completed in 14.025760650634766 sec,
#  output written to deepseek_enu/again-1.json
# API call for 'still' completed in 13.3334801197052 sec,
#  output written to deepseek_enu/still-1.json
# API call for 'always' completed in 15.73935842514038 sec,
#  output written to deepseek_enu/always-1.json
# API call for 'never' completed in 15.19879674911499 sec,
#  output written to deepseek_enu/never-1.json
# API call for 'often' completed in 17.41157627105713 sec,
#  output written to deepseek_enu/often-1.json
# API call for 'sometimes' completed in 15.233105421066284 sec,
#  output written to deepseek_enu/sometimes-1.json
# Failed to process usually:
#  Expecting ',' delimiter: line 26 column 21 (char 2168)
# API call for 'ever' completed in 16.050528049468994 sec,
#  output written to deepseek_enu/ever-1.json
# API call for 'almost' completed in 16.43098282814026 sec,
#  output written to deepseek_enu/almost-1.json
# API call for 'already' completed in 17.670894622802734 sec,
#  output written to deepseek_enu/already-1.json
# API call for 'even' completed in 16.07434391975403 sec,
#  output written to deepseek_enu/even-1.json
# API call for 'only' completed in 16.54143190383911 sec,
#  output written to deepseek_enu/only-1.json
# API call for 'quite' completed in 18.27303719520569 sec,
#  output written to deepseek_enu/quite-1.json
# API call for 'too' completed in 17.01499843597412 sec,
#  output written to deepseek_enu/too-1.json
# Skip enough
# API call for 'however' completed in 16.535000324249268 sec,
#  output written to deepseek_enu/however-1.json
# API call for 'therefore' completed in 14.20945930480957 sec,
#  output written to deepseek_enu/therefore-1.json
# API call for 'finally' completed in 14.159423351287842 sec,
#  output written to deepseek_enu/finally-1.json
# API call for 'recently' completed in 16.112067461013794 sec,
#  output written to deepseek_enu/recently-1.json
# API call for 'especially' completed in 14.300832271575928 sec,
#  output written to deepseek_enu/especially-1.json
# API call for 'particularly' completed in 14.837949514389038 sec,
#  output written to deepseek_enu/particularly-1.json
# API call for 'generally' completed in 12.877944231033325 sec,
#  output written to deepseek_enu/generally-1.json
# API call for 'completely' completed in 17.459843635559082 sec,
#  output written to deepseek_enu/completely-1.json
# API call for 'totally' completed in 17.72020125389099 sec,
#  output written to deepseek_enu/totally-1.json
# API call for 'absolutely' completed in 14.522823810577393 sec,
#  output written to deepseek_enu/absolutely-1.json
# API call for 'simply' completed in 15.881147146224976 sec,
#  output written to deepseek_enu/simply-1.json
# Skip now
# Skip then
# Skip today
# Skip yesterday
# Skip tomorrow
# API call for 'soon' completed in 16.094309091567993 sec,
#  output written to deepseek_enu/soon-1.json
# API call for 'later' completed in 17.908982276916504 sec,
#  output written to deepseek_enu/later-1.json
# API call for 'ago' completed in 14.423182964324951 sec,
#  output written to deepseek_enu/ago-1.json
# Skip before
# Skip after
# Skip always
# API call for 'usually' completed in 17.631588459014893 sec,
#  output written to deepseek_enu/usually-1.json
# Skip often
# Skip sometimes
# API call for 'rarely' completed in 14.111479997634888 sec,
#  output written to deepseek_enu/rarely-1.json
# Skip never
# Skip already
# Skip still
# Skip yet
# Skip here
# Skip there
# API call for 'somewhere' completed in 15.296221256256104 sec,
#  output written to deepseek_enu/somewhere-1.json
# API call for 'anywhere' completed in 13.759302139282227 sec,
#  output written to deepseek_enu/anywhere-1.json
# API call for 'everywhere' completed in 14.918200731277466 sec,
#  output written to deepseek_enu/everywhere-1.json
# API call for 'nowhere' completed in 16.528135538101196 sec,
#  output written to deepseek_enu/nowhere-1.json
# API call for 'inside' completed in 18.040964126586914 sec,
#  output written to deepseek_enu/inside-1.json
# API call for 'outside' completed in 14.18061876296997 sec,
#  output written to deepseek_enu/outside-1.json
# Skip above
# Skip below
# Skip near
# API call for 'far' completed in 11.808616638183594 sec,
#  output written to deepseek_enu/far-1.json
# Skip away
# Skip very
# Skip quite
# API call for 'rather' completed in 15.745802640914917 sec,
#  output written to deepseek_enu/rather-1.json
# API call for 'pretty' completed in 14.741551399230957 sec,
#  output written to deepseek_enu/pretty-1.json
# Skip really
# API call for 'extremely' completed in 13.645999431610107 sec,
#  output written to deepseek_enu/extremely-1.json
# API call for 'incredibly' completed in 15.891935586929321 sec,
#  output written to deepseek_enu/incredibly-1.json
# API call for 'fairly' completed in 13.785226106643677 sec,
#  output written to deepseek_enu/fairly-1.json
# API call for 'somewhat' completed in 14.44550347328186 sec,
#  output written to deepseek_enu/somewhat-1.json
# API call for 'hardly' completed in 16.923108339309692 sec,
#  output written to deepseek_enu/hardly-1.json
# API call for 'barely' completed in 15.254388332366943 sec,
#  output written to deepseek_enu/barely-1.json
# API call for 'slightly' completed in 13.327942371368408 sec,
#  output written to deepseek_enu/slightly-1.json
# Skip always
# Skip usually
# Skip often
# API call for 'frequently' completed in 15.052778244018555 sec,
#  output written to deepseek_enu/frequently-1.json
# Skip sometimes
# API call for 'occasionally' completed in 15.936529874801636 sec,
#  output written to deepseek_enu/occasionally-1.json
# API call for 'seldom' completed in 13.157891035079956 sec,
#  output written to deepseek_enu/seldom-1.json
# Skip rarely
# Skip never
# Skip one
# API call for 'two' completed in 13.67151165008545 sec,
#  output written to deepseek_enu/two-1.json
# API call for 'three' completed in 13.825074434280396 sec,
#  output written to deepseek_enu/three-1.json
# API call for 'four' completed in 15.026630878448486 sec,
#  output written to deepseek_enu/four-1.json
# API call for 'five' completed in 12.01003384590149 sec,
#  output written to deepseek_enu/five-1.json
# API call for 'six' completed in 13.50439167022705 sec,
#  output written to deepseek_enu/six-1.json
# API call for 'seven' completed in 13.886739492416382 sec,
#  output written to deepseek_enu/seven-1.json
# API call for 'eight' completed in 14.060078859329224 sec,
#  output written to deepseek_enu/eight-1.json
# API call for 'nine' completed in 13.05656886100769 sec,
#  output written to deepseek_enu/nine-1.json
# API call for 'ten' completed in 17.882094383239746 sec,
#  output written to deepseek_enu/ten-1.json
# API call for 'eleven' completed in 12.915083169937134 sec,
#  output written to deepseek_enu/eleven-1.json
# API call for 'twelve' completed in 14.667235612869263 sec,
#  output written to deepseek_enu/twelve-1.json
# API call for 'thirteen' completed in 14.656529664993286 sec,
#  output written to deepseek_enu/thirteen-1.json
# API call for 'fourteen' completed in 16.51459312438965 sec,
#  output written to deepseek_enu/fourteen-1.json
# API call for 'fifteen' completed in 13.060023546218872 sec,
#  output written to deepseek_enu/fifteen-1.json
# API call for 'sixteen' completed in 11.869773626327515 sec,
#  output written to deepseek_enu/sixteen-1.json
# API call for 'seventeen' completed in 11.421440124511719 sec,
#  output written to deepseek_enu/seventeen-1.json
# API call for 'eighteen' completed in 13.05386757850647 sec,
#  output written to deepseek_enu/eighteen-1.json
# API call for 'nineteen' completed in 14.346980333328247 sec,
#  output written to deepseek_enu/nineteen-1.json
# API call for 'twenty' completed in 13.254291534423828 sec,
#  output written to deepseek_enu/twenty-1.json
# API call for 'thirty' completed in 13.818271160125732 sec,
#  output written to deepseek_enu/thirty-1.json
# API call for 'forty' completed in 15.624619483947754 sec,
#  output written to deepseek_enu/forty-1.json
# API call for 'fifty' completed in 17.089887619018555 sec,
#  output written to deepseek_enu/fifty-1.json
# API call for 'sixty' completed in 12.142501592636108 sec,
#  output written to deepseek_enu/sixty-1.json
# API call for 'seventy' completed in 13.32294249534607 sec,
#  output written to deepseek_enu/seventy-1.json
# API call for 'eighty' completed in 14.11996603012085 sec,
#  output written to deepseek_enu/eighty-1.json
# API call for 'ninety' completed in 16.676963567733765 sec,
#  output written to deepseek_enu/ninety-1.json
# API call for 'hundred' completed in 17.36783504486084 sec,
#  output written to deepseek_enu/hundred-1.json
# API call for 'thousand' completed in 14.939072370529175 sec,
#  output written to deepseek_enu/thousand-1.json
# API call for 'million' completed in 13.851929187774658 sec,
#  output written to deepseek_enu/million-1.json
# API call for 'billion' completed in 14.831001281738281 sec,
#  output written to deepseek_enu/billion-1.json
# API call for 'first' completed in 15.407866954803467 sec,
#  output written to deepseek_enu/first-1.json
# Skip second
# API call for 'third' completed in 13.778508424758911 sec,
#  output written to deepseek_enu/third-1.json
# API call for 'fourth' completed in 13.628677129745483 sec,
#  output written to deepseek_enu/fourth-1.json
# API call for 'fifth' completed in 14.421861171722412 sec,
#  output written to deepseek_enu/fifth-1.json
# API call for 'last' completed in 15.486669778823853 sec,
#  output written to deepseek_enu/last-1.json
# Skip who
# Skip what
# API call for 'where' completed in 13.979289770126343 sec,
#  output written to deepseek_enu/where-1.json
# API call for 'when' completed in 13.627447366714478 sec,
#  output written to deepseek_enu/when-1.json
# API call for 'why' completed in 16.447404384613037 sec,
#  output written to deepseek_enu/why-1.json
# API call for 'how' completed in 13.438324689865112 sec,
#  output written to deepseek_enu/how-1.json
# Skip which
# Skip whose
# Skip whom

# %%
# !cd
# Out:
# C:\Users\p2p2l\projects\wgong\zistory\zinets\dev\notebook
