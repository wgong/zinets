# %% [markdown]
# Update 100 most commonly used parts or simple Zis

# %%
import pandas as pd 
from utils import *
# Out:
# 2025-02-06 16:21:15.533 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-06 16:21:15.555 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
def create_df_from_list(data_list):
    # Create DataFrame directly from the list of dictionaries
    df = pd.DataFrame(data_list)
    
    # Optional: Convert is_zi to boolean type
#     df['is_zi'] = df['is_zi'].astype(bool)
    
    return df

def merge_zi_dataframes(df1, df2):
    """
    Merge two dataframes on 'zi' column using left merge
    
    Parameters:
    df1: First DataFrame with columns ['zi', 'is_zi']
    df2: Second DataFrame with columns ['zi', 'pinyin']
    
    Returns:
    Merged DataFrame with columns ['zi', 'is_zi', 'pinyin']
    """
    # Perform left merge on 'zi' column
    merged_df = pd.merge(
        left=df1,
        right=df2,
        on='zi',
        how='left'
    ).fillna("")
    
    return merged_df

# %%
DEBUG = False  # True

# %%
file_xlsx = r"elemental_zi_v3.xlsx"

# %%
df = pd.read_excel(file_xlsx, sheet_name="elemental_zi_v3").fillna("")

# %%
df
# Out:
#     zi  is_zi id_kangxi meaning     pinyin  n_strokes term examples variant
# 0    丨      0       2.0    line  gùn / gǔn          1       十、中、串、丰
# 1    丶      0       3.0     dot        zhǔ          1  丶字旁  丸、凡、丹、户
# 2    丿      0             slash        piě          1       乂、乃、久、八
# 3    乀      0             slash        piě          1       乂、乃、久、八
# 4    乁      0             slash        piě          1
# ..  ..    ...       ...     ...        ...        ...  ...      ...     ...
# 417  黄      1            yellow      huáng         12                     黃
# 418  黑      1     203.0   black        hēi         12         墨、黓、黔
# 419  鼓      1     207.0    drum         gǔ         13         鼕、鼖、鼗       鼔
# 420  鼻      1     209.0    nose         bí         14         鼽、鼾、齁
# 421  鹿      1     198.0    dear         lù         11         麀、麁、麂
#
# [422 rows x 9 columns]

# %%
with DBConn() as _conn:
    df.to_sql("t_elemental_zi", _conn, if_exists="replace", index=False)

# %%
elements = df["zi"].to_list()

# %%
len(elements) , elements[:10]
# Out:
# (422, ['丨', '丶', '丿', '乀', '乁', '乚', '乛', '亅', '一', '乙'])

# %% [markdown]
# ### Frequency

# %%
data_freq = []
with DBConn() as _conn:
    for x in elements:
        
        if x not in ['日', '乙', '口', '目'] and DEBUG: continue 

        sql_1 = f""" 
with hot1 as (
	select 
		  case when zi_left_up = '{x}' then 1 else 0 end as n_left_up
		, case when zi_left = '{x}' then 1 else 0 end as n_left
		, case when zi_left_down = '{x}' then 1 else 0 end as n_left_down
		, case when zi_up = '{x}' then 1 else 0 end as n_up
		, case when zi_mid = '{x}' then 1 else 0 end as n_mid
		, case when zi_down = '{x}' then 1 else 0 end as n_down
		, case when zi_right_up = '{x}' then 1 else 0 end as n_right_up
		, case when zi_right = '{x}' then 1 else 0 end as n_right
		, case when zi_right_down = '{x}' then 1 else 0 end as n_right_down
		, case when zi_mid_in = '{x}' then 1 else 0 end as n_mid_in
		, case when zi_mid_out = '{x}' then 1 else 0 end as n_mid_out
	from t_zi_part 
)
, sum1 as (
	select 
		sum(n_left_up) as n1, sum(n_left) as n2, sum(n_left_down) as n3,
		sum(n_up) as n4, sum(n_mid) as n5, sum(n_down) as n6,
		sum(n_right_up) as n7, sum(n_right) as n8, sum(n_right_down) as n9,
		sum(n_mid_in) as n10, sum(n_mid_out) as n11
	from hot1
)
select '{x}' as zi, (n1+n2+n3+n4+n5+n6+n7+n8+n9+n10+n11) as n_frequency
from sum1
;        
        
        """
        df_1 = pd.read_sql(sql_1, _conn)
        r = df_1.to_dict("records")
        print(r)
        data_freq += r
        
#         n_frequency = r[0].get('freq', 0)
#         sql_stmt = f"""
#             update t_elemental_zi 
#             set n_frequency = '{n_frequency}'
#                 where zi='{x}' and n_frequency is null 
#             ;
#         """
#         print(sql_stmt)
#         db_run_sql(sql_stmt, _conn, debug=False)
# Out:
# [{'zi': '丨', 'n_frequency': 25}]
# [{'zi': '丶', 'n_frequency': 26}]
# [{'zi': '丿', 'n_frequency': 40}]
# [{'zi': '乀', 'n_frequency': 3}]
# [{'zi': '乁', 'n_frequency': 1}]
# [{'zi': '乚', 'n_frequency': 9}]
# [{'zi': '乛', 'n_frequency': 3}]
# [{'zi': '亅', 'n_frequency': 1}]
# [{'zi': '一', 'n_frequency': 73}]
# [{'zi': '乙', 'n_frequency': 11}]
# [{'zi': '⺀', 'n_frequency': 0}]
# [{'zi': '丷', 'n_frequency': 26}]
# [{'zi': '乂', 'n_frequency': 23}]
# [{'zi': '龴', 'n_frequency': 2}]
# [{'zi': '亠', 'n_frequency': 27}]
# [{'zi': '亻', 'n_frequency': 213}]
# [{'zi': '冂', 'n_frequency': 17}]
# [{'zi': '冖', 'n_frequency': 35}]
# [{'zi': '冫', 'n_frequency': 29}]
# [{'zi': '凵', 'n_frequency': 7}]
# [{'zi': '⺈', 'n_frequency': 0}]
# [{'zi': '刂', 'n_frequency': 45}]
# [{'zi': '勹', 'n_frequency': 14}]
# [{'zi': '匚', 'n_frequency': 14}]
# [{'zi': '匸', 'n_frequency': 5}]
# [{'zi': '卩', 'n_frequency': 8}]
# [{'zi': '㔾', 'n_frequency': 6}]
# [{'zi': '⺁', 'n_frequency': 0}]
# [{'zi': '厶', 'n_frequency': 25}]
# [{'zi': '讠', 'n_frequency': 102}]
# [{'zi': '丁', 'n_frequency': 15}]
# [{'zi': '七', 'n_frequency': 4}]
# [{'zi': '乃', 'n_frequency': 8}]
# [{'zi': '九', 'n_frequency': 16}]
# [{'zi': '了', 'n_frequency': 5}]
# [{'zi': '二', 'n_frequency': 20}]
# [{'zi': '人', 'n_frequency': 46}]
# [{'zi': '儿', 'n_frequency': 12}]
# [{'zi': '入', 'n_frequency': 1}]
# [{'zi': '八', 'n_frequency': 28}]
# [{'zi': '几', 'n_frequency': 24}]
# [{'zi': '刀', 'n_frequency': 32}]
# [{'zi': '刁', 'n_frequency': 1}]
# [{'zi': '力', 'n_frequency': 53}]
# [{'zi': '匕', 'n_frequency': 20}]
# [{'zi': '十', 'n_frequency': 56}]
# [{'zi': '卜', 'n_frequency': 17}]
# [{'zi': '厂', 'n_frequency': 32}]
# [{'zi': '又', 'n_frequency': 73}]
# [{'zi': '亍', 'n_frequency': 1}]
# [{'zi': '兀', 'n_frequency': 5}]
# [{'zi': '夂', 'n_frequency': 15}]
# [{'zi': '夊', 'n_frequency': 1}]
# [{'zi': '宀', 'n_frequency': 63}]
# [{'zi': '⺌', 'n_frequency': 1}]
# [{'zi': '⺍', 'n_frequency': 0}]
# [{'zi': '尢', 'n_frequency': 1}]
# [{'zi': '屮', 'n_frequency': 2}]
# [{'zi': '巛', 'n_frequency': 4}]
# [{'zi': '廴', 'n_frequency': 3}]
# [{'zi': '彐', 'n_frequency': 13}]
# [{'zi': '彑', 'n_frequency': 3}]
# [{'zi': '彡', 'n_frequency': 23}]
# [{'zi': '彳', 'n_frequency': 28}]
# [{'zi': '忄', 'n_frequency': 116}]
# [{'zi': '扌', 'n_frequency': 261}]
# [{'zi': '氵', 'n_frequency': 377}]
# [{'zi': '丬', 'n_frequency': 10}]
# [{'zi': '纟', 'n_frequency': 111}]
# [{'zi': '艹', 'n_frequency': 284}]
# [{'zi': '辶', 'n_frequency': 90}]
# [{'zi': '⻏', 'n_frequency': 1}]
# [{'zi': '阝', 'n_frequency': 153}]
# [{'zi': '饣', 'n_frequency': 32}]
# [{'zi': '万', 'n_frequency': 2}]
# [{'zi': '丈', 'n_frequency': 2}]
# [{'zi': '三', 'n_frequency': 7}]
# [{'zi': '上', 'n_frequency': 3}]
# [{'zi': '下', 'n_frequency': 3}]
# [{'zi': '与', 'n_frequency': 2}]
# [{'zi': '个', 'n_frequency': 0}]
# [{'zi': '丸', 'n_frequency': 5}]
# [{'zi': '义', 'n_frequency': 3}]
# [{'zi': '久', 'n_frequency': 6}]
# [{'zi': '么', 'n_frequency': 0}]
# [{'zi': '之', 'n_frequency': 4}]
# [{'zi': '乞', 'n_frequency': 8}]
# [{'zi': '也', 'n_frequency': 13}]
# [{'zi': '习', 'n_frequency': 2}]
# [{'zi': '于', 'n_frequency': 10}]
# [{'zi': '亏', 'n_frequency': 7}]
# [{'zi': '亡', 'n_frequency': 18}]
# [{'zi': '刃', 'n_frequency': 8}]
# [{'zi': '勺', 'n_frequency': 14}]
# [{'zi': '千', 'n_frequency': 10}]
# [{'zi': '叉', 'n_frequency': 3}]
# [{'zi': '及', 'n_frequency': 11}]
# [{'zi': '口', 'n_frequency': 300}]
# [{'zi': '囗', 'n_frequency': 22}]
# [{'zi': '土', 'n_frequency': 143}]
# [{'zi': '士', 'n_frequency': 22}]
# [{'zi': '夕', 'n_frequency': 17}]
# [{'zi': '大', 'n_frequency': 44}]
# [{'zi': '女', 'n_frequency': 137}]
# [{'zi': '子', 'n_frequency': 28}]
# [{'zi': '寸', 'n_frequency': 31}]
# [{'zi': '小', 'n_frequency': 22}]
# [{'zi': '尸', 'n_frequency': 27}]
# [{'zi': '山', 'n_frequency': 65}]
# [{'zi': '川', 'n_frequency': 6}]
# [{'zi': '工', 'n_frequency': 24}]
# [{'zi': '己', 'n_frequency': 15}]
# [{'zi': '已', 'n_frequency': 0}]
# [{'zi': '巾', 'n_frequency': 55}]
# [{'zi': '干', 'n_frequency': 23}]
# [{'zi': '乡', 'n_frequency': 0}]
# [{'zi': '幺', 'n_frequency': 8}]
# [{'zi': '广', 'n_frequency': 42}]
# [{'zi': '廾', 'n_frequency': 13}]
# [{'zi': '弋', 'n_frequency': 6}]
# [{'zi': '弓', 'n_frequency': 24}]
# [{'zi': '才', 'n_frequency': 8}]
# [{'zi': '犭', 'n_frequency': 51}]
# [{'zi': '门', 'n_frequency': 22}]
# [{'zi': '飞', 'n_frequency': 0}]
# [{'zi': '马', 'n_frequency': 44}]
# [{'zi': '攴', 'n_frequency': 2}]
# [{'zi': '攵', 'n_frequency': 59}]
# [{'zi': '旡', 'n_frequency': 3}]
# [{'zi': '朩', 'n_frequency': 1}]
# [{'zi': '殳', 'n_frequency': 37}]
# [{'zi': '灬', 'n_frequency': 20}]
# [{'zi': '爫', 'n_frequency': 9}]
# [{'zi': '爻', 'n_frequency': 4}]
# [{'zi': '爿', 'n_frequency': 5}]
# [{'zi': '⺧', 'n_frequency': 2}]
# [{'zi': '牜', 'n_frequency': 15}]
# [{'zi': '⺩', 'n_frequency': 0}]
# [{'zi': '礻', 'n_frequency': 38}]
# [{'zi': '禸', 'n_frequency': 1}]
# [{'zi': '罓', 'n_frequency': 0}]
# [{'zi': '耂', 'n_frequency': 3}]
# [{'zi': '不', 'n_frequency': 11}]
# [{'zi': '丑', 'n_frequency': 7}]
# [{'zi': '专', 'n_frequency': 3}]
# [{'zi': '中', 'n_frequency': 12}]
# [{'zi': '丰', 'n_frequency': 14}]
# [{'zi': '为', 'n_frequency': 1}]
# [{'zi': '乌', 'n_frequency': 2}]
# [{'zi': '云', 'n_frequency': 12}]
# [{'zi': '五', 'n_frequency': 2}]
# [{'zi': '井', 'n_frequency': 7}]
# [{'zi': '亢', 'n_frequency': 11}]
# [{'zi': '今', 'n_frequency': 16}]
# [{'zi': '介', 'n_frequency': 8}]
# [{'zi': '仓', 'n_frequency': 8}]
# [{'zi': '以', 'n_frequency': 3}]
# [{'zi': '元', 'n_frequency': 13}]
# [{'zi': '公', 'n_frequency': 8}]
# [{'zi': '六', 'n_frequency': 2}]
# [{'zi': '内', 'n_frequency': 10}]
# [{'zi': '冈', 'n_frequency': 3}]
# [{'zi': '凶', 'n_frequency': 3}]
# [{'zi': '分', 'n_frequency': 24}]
# [{'zi': '办', 'n_frequency': 2}]
# [{'zi': '勾', 'n_frequency': 4}]
# [{'zi': '勿', 'n_frequency': 10}]
# [{'zi': '匀', 'n_frequency': 3}]
# [{'zi': '匹', 'n_frequency': 1}]
# [{'zi': '区', 'n_frequency': 9}]
# [{'zi': '升', 'n_frequency': 1}]
# [{'zi': '午', 'n_frequency': 4}]
# [{'zi': '友', 'n_frequency': 2}]
# [{'zi': '天', 'n_frequency': 9}]
# [{'zi': '太', 'n_frequency': 2}]
# [{'zi': '夫', 'n_frequency': 27}]
# [{'zi': '少', 'n_frequency': 14}]
# [{'zi': '尤', 'n_frequency': 9}]
# [{'zi': '尺', 'n_frequency': 2}]
# [{'zi': '屯', 'n_frequency': 13}]
# [{'zi': '巨', 'n_frequency': 9}]
# [{'zi': '巴', 'n_frequency': 15}]
# [{'zi': '开', 'n_frequency': 3}]
# [{'zi': '心', 'n_frequency': 84}]
# [{'zi': '戈', 'n_frequency': 33}]
# [{'zi': '戶', 'n_frequency': 6}]
# [{'zi': '户', 'n_frequency': 13}]
# [{'zi': '手', 'n_frequency': 18}]
# [{'zi': '支', 'n_frequency': 13}]
# [{'zi': '文', 'n_frequency': 16}]
# [{'zi': '斗', 'n_frequency': 16}]
# [{'zi': '斤', 'n_frequency': 23}]
# [{'zi': '方', 'n_frequency': 27}]
# [{'zi': '无', 'n_frequency': 3}]
# [{'zi': '日', 'n_frequency': 125}]
# [{'zi': '曰', 'n_frequency': 14}]
# [{'zi': '月', 'n_frequency': 154}]
# [{'zi': '木', 'n_frequency': 324}]
# [{'zi': '欠', 'n_frequency': 42}]
# [{'zi': '止', 'n_frequency': 21}]
# [{'zi': '歹', 'n_frequency': 17}]
# [{'zi': '毋', 'n_frequency': 1}]
# [{'zi': '比', 'n_frequency': 16}]
# [{'zi': '毛', 'n_frequency': 22}]
# [{'zi': '氏', 'n_frequency': 8}]
# [{'zi': '气', 'n_frequency': 24}]
# [{'zi': '水', 'n_frequency': 20}]
# [{'zi': '火', 'n_frequency': 85}]
# [{'zi': '爪', 'n_frequency': 3}]
# [{'zi': '父', 'n_frequency': 5}]
# [{'zi': '片', 'n_frequency': 6}]
# [{'zi': '牙', 'n_frequency': 9}]
# [{'zi': '牛', 'n_frequency': 11}]
# [{'zi': '犬', 'n_frequency': 22}]
# [{'zi': '王', 'n_frequency': 113}]
# [{'zi': '瓦', 'n_frequency': 16}]
# [{'zi': '见', 'n_frequency': 10}]
# [{'zi': '贝', 'n_frequency': 59}]
# [{'zi': '车', 'n_frequency': 53}]
# [{'zi': '长', 'n_frequency': 5}]
# [{'zi': '韦', 'n_frequency': 8}]
# [{'zi': '风', 'n_frequency': 5}]
# [{'zi': '乍', 'n_frequency': 13}]
# [{'zi': '刍', 'n_frequency': 6}]
# [{'zi': '戋', 'n_frequency': 8}]
# [{'zi': '氺', 'n_frequency': 0}]
# [{'zi': '疋', 'n_frequency': 7}]
# [{'zi': '𤴔', 'n_frequency': 0}]
# [{'zi': '疒', 'n_frequency': 74}]
# [{'zi': '癶', 'n_frequency': 2}]
# [{'zi': '罒', 'n_frequency': 34}]
# [{'zi': '衤', 'n_frequency': 52}]
# [{'zi': '钅', 'n_frequency': 88}]
# [{'zi': '且', 'n_frequency': 24}]
# [{'zi': '丘', 'n_frequency': 5}]
# [{'zi': '丙', 'n_frequency': 6}]
# [{'zi': '业', 'n_frequency': 5}]
# [{'zi': '东', 'n_frequency': 6}]
# [{'zi': '乎', 'n_frequency': 1}]
# [{'zi': '乐', 'n_frequency': 2}]
# [{'zi': '令', 'n_frequency': 21}]
# [{'zi': '兄', 'n_frequency': 5}]
# [{'zi': '兰', 'n_frequency': 3}]
# [{'zi': '冬', 'n_frequency': 4}]
# [{'zi': '出', 'n_frequency': 8}]
# [{'zi': '击', 'n_frequency': 1}]
# [{'zi': '包', 'n_frequency': 15}]
# [{'zi': '北', 'n_frequency': 7}]
# [{'zi': '半', 'n_frequency': 11}]
# [{'zi': '占', 'n_frequency': 21}]
# [{'zi': '卡', 'n_frequency': 0}]
# [{'zi': '去', 'n_frequency': 11}]
# [{'zi': '古', 'n_frequency': 19}]
# [{'zi': '句', 'n_frequency': 19}]
# [{'zi': '另', 'n_frequency': 2}]
# [{'zi': '只', 'n_frequency': 10}]
# [{'zi': '可', 'n_frequency': 17}]
# [{'zi': '台', 'n_frequency': 17}]
# [{'zi': '四', 'n_frequency': 3}]
# [{'zi': '央', 'n_frequency': 11}]
# [{'zi': '失', 'n_frequency': 14}]
# [{'zi': '头', 'n_frequency': 2}]
# [{'zi': '宁', 'n_frequency': 5}]
# [{'zi': '它', 'n_frequency': 8}]
# [{'zi': '尼', 'n_frequency': 7}]
# [{'zi': '市', 'n_frequency': 2}]
# [{'zi': '布', 'n_frequency': 2}]
# [{'zi': '平', 'n_frequency': 9}]
# [{'zi': '必', 'n_frequency': 15}]
# [{'zi': '斥', 'n_frequency': 2}]
# [{'zi': '旦', 'n_frequency': 17}]
# [{'zi': '未', 'n_frequency': 10}]
# [{'zi': '末', 'n_frequency': 5}]
# [{'zi': '本', 'n_frequency': 2}]
# [{'zi': '术', 'n_frequency': 4}]
# [{'zi': '正', 'n_frequency': 9}]
# [{'zi': '母', 'n_frequency': 6}]
# [{'zi': '玄', 'n_frequency': 7}]
# [{'zi': '玉', 'n_frequency': 5}]
# [{'zi': '瓜', 'n_frequency': 12}]
# [{'zi': '甘', 'n_frequency': 12}]
# [{'zi': '生', 'n_frequency': 11}]
# [{'zi': '用', 'n_frequency': 5}]
# [{'zi': '田', 'n_frequency': 51}]
# [{'zi': '由', 'n_frequency': 21}]
# [{'zi': '甲', 'n_frequency': 10}]
# [{'zi': '申', 'n_frequency': 9}]
# [{'zi': '电', 'n_frequency': 3}]
# [{'zi': '白', 'n_frequency': 32}]
# [{'zi': '皮', 'n_frequency': 17}]
# [{'zi': '皿', 'n_frequency': 30}]
# [{'zi': '目', 'n_frequency': 79}]
# [{'zi': '矛', 'n_frequency': 8}]
# [{'zi': '矢', 'n_frequency': 16}]
# [{'zi': '石', 'n_frequency': 71}]
# [{'zi': '示', 'n_frequency': 13}]
# [{'zi': '禾', 'n_frequency': 78}]
# [{'zi': '穴', 'n_frequency': 41}]
# [{'zi': '立', 'n_frequency': 34}]
# [{'zi': '鸟', 'n_frequency': 62}]
# [{'zi': '龙', 'n_frequency': 10}]
# [{'zi': '囟', 'n_frequency': 2}]
# [{'zi': '尧', 'n_frequency': 9}]
# [{'zi': '屰', 'n_frequency': 3}]
# [{'zi': '⺮', 'n_frequency': 108}]
# [{'zi': '⺶', 'n_frequency': 0}]
# [{'zi': '⺷', 'n_frequency': 1}]
# [{'zi': '聿', 'n_frequency': 5}]
# [{'zi': '艮', 'n_frequency': 19}]
# [{'zi': '虍', 'n_frequency': 12}]
# [{'zi': '覀', 'n_frequency': 7}]
# [{'zi': '交', 'n_frequency': 19}]
# [{'zi': '共', 'n_frequency': 15}]
# [{'zi': '各', 'n_frequency': 20}]
# [{'zi': '合', 'n_frequency': 18}]
# [{'zi': '吉', 'n_frequency': 14}]
# [{'zi': '向', 'n_frequency': 3}]
# [{'zi': '吕', 'n_frequency': 4}]
# [{'zi': '寺', 'n_frequency': 11}]
# [{'zi': '并', 'n_frequency': 6}]
# [{'zi': '庄', 'n_frequency': 3}]
# [{'zi': '式', 'n_frequency': 2}]
# [{'zi': '曲', 'n_frequency': 1}]
# [{'zi': '竹', 'n_frequency': 1}]
# [{'zi': '米', 'n_frequency': 51}]
# [{'zi': '糸', 'n_frequency': 32}]
# [{'zi': '缶', 'n_frequency': 16}]
# [{'zi': '网', 'n_frequency': 2}]
# [{'zi': '羊', 'n_frequency': 37}]
# [{'zi': '羽', 'n_frequency': 42}]
# [{'zi': '老', 'n_frequency': 2}]
# [{'zi': '而', 'n_frequency': 11}]
# [{'zi': '耒', 'n_frequency': 7}]
# [{'zi': '耳', 'n_frequency': 31}]
# [{'zi': '肉', 'n_frequency': 3}]
# [{'zi': '臣', 'n_frequency': 6}]
# [{'zi': '自', 'n_frequency': 9}]
# [{'zi': '至', 'n_frequency': 12}]
# [{'zi': '臼', 'n_frequency': 10}]
# [{'zi': '舌', 'n_frequency': 19}]
# [{'zi': '舟', 'n_frequency': 18}]
# [{'zi': '色', 'n_frequency': 3}]
# [{'zi': '虫', 'n_frequency': 132}]
# [{'zi': '血', 'n_frequency': 6}]
# [{'zi': '行', 'n_frequency': 12}]
# [{'zi': '衣', 'n_frequency': 25}]
# [{'zi': '西', 'n_frequency': 6}]
# [{'zi': '页', 'n_frequency': 44}]
# [{'zi': '齐', 'n_frequency': 5}]
# [{'zi': '㐬', 'n_frequency': 4}]
# [{'zi': '佥', 'n_frequency': 10}]
# [{'zi': '呙', 'n_frequency': 5}]
# [{'zi': '坙', 'n_frequency': 8}]
# [{'zi': '夆', 'n_frequency': 4}]
# [{'zi': '奂', 'n_frequency': 5}]
# [{'zi': '孚', 'n_frequency': 9}]
# [{'zi': '肙', 'n_frequency': 12}]
# [{'zi': '豕', 'n_frequency': 15}]
# [{'zi': '豸', 'n_frequency': 10}]
# [{'zi': '酉', 'n_frequency': 46}]
# [{'zi': '卤', 'n_frequency': 0}]
# [{'zi': '员', 'n_frequency': 4}]
# [{'zi': '㕻', 'n_frequency': 0}]
# [{'zi': '甫', 'n_frequency': 23}]
# [{'zi': '舛', 'n_frequency': 2}]
# [{'zi': '良', 'n_frequency': 13}]
# [{'zi': '角', 'n_frequency': 17}]
# [{'zi': '言', 'n_frequency': 36}]
# [{'zi': '谷', 'n_frequency': 9}]
# [{'zi': '豆', 'n_frequency': 11}]
# [{'zi': '赤', 'n_frequency': 7}]
# [{'zi': '走', 'n_frequency': 23}]
# [{'zi': '足', 'n_frequency': 76}]
# [{'zi': '身', 'n_frequency': 5}]
# [{'zi': '辛', 'n_frequency': 18}]
# [{'zi': '辰', 'n_frequency': 9}]
# [{'zi': '邑', 'n_frequency': 8}]
# [{'zi': '釆', 'n_frequency': 2}]
# [{'zi': '里', 'n_frequency': 13}]
# [{'zi': '麦', 'n_frequency': 1}]
# [{'zi': '龟', 'n_frequency': 0}]
# [{'zi': '龺', 'n_frequency': 1}]
# [{'zi': '幷', 'n_frequency': 3}]
# [{'zi': '隹', 'n_frequency': 53}]
# [{'zi': '黾', 'n_frequency': 2}]
# [{'zi': '其', 'n_frequency': 17}]
# [{'zi': '奉', 'n_frequency': 5}]
# [{'zi': '尚', 'n_frequency': 15}]
# [{'zi': '易', 'n_frequency': 15}]
# [{'zi': '東', 'n_frequency': 1}]
# [{'zi': '责', 'n_frequency': 2}]
# [{'zi': '金', 'n_frequency': 18}]
# [{'zi': '阜', 'n_frequency': 1}]
# [{'zi': '隶', 'n_frequency': 3}]
# [{'zi': '雨', 'n_frequency': 28}]
# [{'zi': '青', 'n_frequency': 15}]
# [{'zi': '非', 'n_frequency': 30}]
# [{'zi': '鱼', 'n_frequency': 23}]
# [{'zi': '齿', 'n_frequency': 7}]
# [{'zi': '畐', 'n_frequency': 11}]
# [{'zi': '咸', 'n_frequency': 8}]
# [{'zi': '柬', 'n_frequency': 3}]
# [{'zi': '畏', 'n_frequency': 7}]
# [{'zi': '禺 ', 'n_frequency': 0}]
# [{'zi': '面', 'n_frequency': 5}]
# [{'zi': '革', 'n_frequency': 34}]
# [{'zi': '韭', 'n_frequency': 1}]
# [{'zi': '音', 'n_frequency': 12}]
# [{'zi': '食', 'n_frequency': 9}]
# [{'zi': '首', 'n_frequency': 2}]
# [{'zi': '香', 'n_frequency': 2}]
# [{'zi': '骨', 'n_frequency': 16}]
# [{'zi': '鬼', 'n_frequency': 24}]
# [{'zi': '高', 'n_frequency': 15}]
# [{'zi': '鬥', 'n_frequency': 1}]
# [{'zi': '麻', 'n_frequency': 10}]
# [{'zi': '黍', 'n_frequency': 1}]
# [{'zi': '黄', 'n_frequency': 0}]
# [{'zi': '黑', 'n_frequency': 23}]
# [{'zi': '鼓', 'n_frequency': 3}]
# [{'zi': '鼻', 'n_frequency': 3}]
# [{'zi': '鹿', 'n_frequency': 15}]

# %%
data_freq
# Out:
# [{'zi': '丨', 'n_frequency': 25},
#  {'zi': '丶', 'n_frequency': 26},
#  {'zi': '丿', 'n_frequency': 40},
#  {'zi': '乀', 'n_frequency': 3},
#  {'zi': '乁', 'n_frequency': 1},
#  {'zi': '乚', 'n_frequency': 9},
#  {'zi': '乛', 'n_frequency': 3},
#  {'zi': '亅', 'n_frequency': 1},
#  {'zi': '一', 'n_frequency': 73},
#  {'zi': '乙', 'n_frequency': 11},
#  {'zi': '⺀', 'n_frequency': 0},
#  {'zi': '丷', 'n_frequency': 26},
#  {'zi': '乂', 'n_frequency': 23},
#  {'zi': '龴', 'n_frequency': 2},
#  {'zi': '亠', 'n_frequency': 27},
#  {'zi': '亻', 'n_frequency': 213},
#  {'zi': '冂', 'n_frequency': 17},
#  {'zi': '冖', 'n_frequency': 35},
#  {'zi': '冫', 'n_frequency': 29},
#  {'zi': '凵', 'n_frequency': 7},
#  {'zi': '⺈', 'n_frequency': 0},
#  {'zi': '刂', 'n_frequency': 45},
#  {'zi': '勹', 'n_frequency': 14},
#  {'zi': '匚', 'n_frequency': 14},
#  {'zi': '匸', 'n_frequency': 5},
#  {'zi': '卩', 'n_frequency': 8},
#  {'zi': '㔾', 'n_frequency': 6},
#  {'zi': '⺁', 'n_frequency': 0},
#  {'zi': '厶', 'n_frequency': 25},
#  {'zi': '讠', 'n_frequency': 102},
#  {'zi': '丁', 'n_frequency': 15},
#  {'zi': '七', 'n_frequency': 4},
#  {'zi': '乃', 'n_frequency': 8},
#  {'zi': '九', 'n_frequency': 16},
#  {'zi': '了', 'n_frequency': 5},
#  {'zi': '二', 'n_frequency': 20},
#  {'zi': '人', 'n_frequency': 46},
#  {'zi': '儿', 'n_frequency': 12},
#  {'zi': '入', 'n_frequency': 1},
#  {'zi': '八', 'n_frequency': 28},
#  {'zi': '几', 'n_frequency': 24},
#  {'zi': '刀', 'n_frequency': 32},
#  {'zi': '刁', 'n_frequency': 1},
#  {'zi': '力', 'n_frequency': 53},
#  {'zi': '匕', 'n_frequency': 20},
#  {'zi': '十', 'n_frequency': 56},
#  {'zi': '卜', 'n_frequency': 17},
#  {'zi': '厂', 'n_frequency': 32},
#  {'zi': '又', 'n_frequency': 73},
#  {'zi': '亍', 'n_frequency': 1},
#  {'zi': '兀', 'n_frequency': 5},
#  {'zi': '夂', 'n_frequency': 15},
#  {'zi': '夊', 'n_frequency': 1},
#  {'zi': '宀', 'n_frequency': 63},
#  {'zi': '⺌', 'n_frequency': 1},
#  {'zi': '⺍', 'n_frequency': 0},
#  {'zi': '尢', 'n_frequency': 1},
#  {'zi': '屮', 'n_frequency': 2},
#  {'zi': '巛', 'n_frequency': 4},
#  {'zi': '廴', 'n_frequency': 3},
#  {'zi': '彐', 'n_frequency': 13},
#  {'zi': '彑', 'n_frequency': 3},
#  {'zi': '彡', 'n_frequency': 23},
#  {'zi': '彳', 'n_frequency': 28},
#  {'zi': '忄', 'n_frequency': 116},
#  {'zi': '扌', 'n_frequency': 261},
#  {'zi': '氵', 'n_frequency': 377},
#  {'zi': '丬', 'n_frequency': 10},
#  {'zi': '纟', 'n_frequency': 111},
#  {'zi': '艹', 'n_frequency': 284},
#  {'zi': '辶', 'n_frequency': 90},
#  {'zi': '⻏', 'n_frequency': 1},
#  {'zi': '阝', 'n_frequency': 153},
#  {'zi': '饣', 'n_frequency': 32},
#  {'zi': '万', 'n_frequency': 2},
#  {'zi': '丈', 'n_frequency': 2},
#  {'zi': '三', 'n_frequency': 7},
#  {'zi': '上', 'n_frequency': 3},
#  {'zi': '下', 'n_frequency': 3},
#  {'zi': '与', 'n_frequency': 2},
#  {'zi': '个', 'n_frequency': 0},
#  {'zi': '丸', 'n_frequency': 5},
#  {'zi': '义', 'n_frequency': 3},
#  {'zi': '久', 'n_frequency': 6},
#  {'zi': '么', 'n_frequency': 0},
#  {'zi': '之', 'n_frequency': 4},
#  {'zi': '乞', 'n_frequency': 8},
#  {'zi': '也', 'n_frequency': 13},
#  {'zi': '习', 'n_frequency': 2},
#  {'zi': '于', 'n_frequency': 10},
#  {'zi': '亏', 'n_frequency': 7},
#  {'zi': '亡', 'n_frequency': 18},
#  {'zi': '刃', 'n_frequency': 8},
#  {'zi': '勺', 'n_frequency': 14},
#  {'zi': '千', 'n_frequency': 10},
#  {'zi': '叉', 'n_frequency': 3},
#  {'zi': '及', 'n_frequency': 11},
#  {'zi': '口', 'n_frequency': 300},
#  {'zi': '囗', 'n_frequency': 22},
#  {'zi': '土', 'n_frequency': 143},
#  {'zi': '士', 'n_frequency': 22},
#  {'zi': '夕', 'n_frequency': 17},
#  {'zi': '大', 'n_frequency': 44},
#  {'zi': '女', 'n_frequency': 137},
#  {'zi': '子', 'n_frequency': 28},
#  {'zi': '寸', 'n_frequency': 31},
#  {'zi': '小', 'n_frequency': 22},
#  {'zi': '尸', 'n_frequency': 27},
#  {'zi': '山', 'n_frequency': 65},
#  {'zi': '川', 'n_frequency': 6},
#  {'zi': '工', 'n_frequency': 24},
#  {'zi': '己', 'n_frequency': 15},
#  {'zi': '已', 'n_frequency': 0},
#  {'zi': '巾', 'n_frequency': 55},
#  {'zi': '干', 'n_frequency': 23},
#  {'zi': '乡', 'n_frequency': 0},
#  {'zi': '幺', 'n_frequency': 8},
#  {'zi': '广', 'n_frequency': 42},
#  {'zi': '廾', 'n_frequency': 13},
#  {'zi': '弋', 'n_frequency': 6},
#  {'zi': '弓', 'n_frequency': 24},
#  {'zi': '才', 'n_frequency': 8},
#  {'zi': '犭', 'n_frequency': 51},
#  {'zi': '门', 'n_frequency': 22},
#  {'zi': '飞', 'n_frequency': 0},
#  {'zi': '马', 'n_frequency': 44},
#  {'zi': '攴', 'n_frequency': 2},
#  {'zi': '攵', 'n_frequency': 59},
#  {'zi': '旡', 'n_frequency': 3},
#  {'zi': '朩', 'n_frequency': 1},
#  {'zi': '殳', 'n_frequency': 37},
#  {'zi': '灬', 'n_frequency': 20},
#  {'zi': '爫', 'n_frequency': 9},
#  {'zi': '爻', 'n_frequency': 4},
#  {'zi': '爿', 'n_frequency': 5},
#  {'zi': '⺧', 'n_frequency': 2},
#  {'zi': '牜', 'n_frequency': 15},
#  {'zi': '⺩', 'n_frequency': 0},
#  {'zi': '礻', 'n_frequency': 38},
#  {'zi': '禸', 'n_frequency': 1},
#  {'zi': '罓', 'n_frequency': 0},
#  {'zi': '耂', 'n_frequency': 3},
#  {'zi': '不', 'n_frequency': 11},
#  {'zi': '丑', 'n_frequency': 7},
#  {'zi': '专', 'n_frequency': 3},
#  {'zi': '中', 'n_frequency': 12},
#  {'zi': '丰', 'n_frequency': 14},
#  {'zi': '为', 'n_frequency': 1},
#  {'zi': '乌', 'n_frequency': 2},
#  {'zi': '云', 'n_frequency': 12},
#  {'zi': '五', 'n_frequency': 2},
#  {'zi': '井', 'n_frequency': 7},
#  {'zi': '亢', 'n_frequency': 11},
#  {'zi': '今', 'n_frequency': 16},
#  {'zi': '介', 'n_frequency': 8},
#  {'zi': '仓', 'n_frequency': 8},
#  {'zi': '以', 'n_frequency': 3},
#  {'zi': '元', 'n_frequency': 13},
#  {'zi': '公', 'n_frequency': 8},
#  {'zi': '六', 'n_frequency': 2},
#  {'zi': '内', 'n_frequency': 10},
#  {'zi': '冈', 'n_frequency': 3},
#  {'zi': '凶', 'n_frequency': 3},
#  {'zi': '分', 'n_frequency': 24},
#  {'zi': '办', 'n_frequency': 2},
#  {'zi': '勾', 'n_frequency': 4},
#  {'zi': '勿', 'n_frequency': 10},
#  {'zi': '匀', 'n_frequency': 3},
#  {'zi': '匹', 'n_frequency': 1},
#  {'zi': '区', 'n_frequency': 9},
#  {'zi': '升', 'n_frequency': 1},
#  {'zi': '午', 'n_frequency': 4},
#  {'zi': '友', 'n_frequency': 2},
#  {'zi': '天', 'n_frequency': 9},
#  {'zi': '太', 'n_frequency': 2},
#  {'zi': '夫', 'n_frequency': 27},
#  {'zi': '少', 'n_frequency': 14},
#  {'zi': '尤', 'n_frequency': 9},
#  {'zi': '尺', 'n_frequency': 2},
#  {'zi': '屯', 'n_frequency': 13},
#  {'zi': '巨', 'n_frequency': 9},
#  {'zi': '巴', 'n_frequency': 15},
#  {'zi': '开', 'n_frequency': 3},
#  {'zi': '心', 'n_frequency': 84},
#  {'zi': '戈', 'n_frequency': 33},
#  {'zi': '戶', 'n_frequency': 6},
#  {'zi': '户', 'n_frequency': 13},
#  {'zi': '手', 'n_frequency': 18},
#  {'zi': '支', 'n_frequency': 13},
#  {'zi': '文', 'n_frequency': 16},
#  {'zi': '斗', 'n_frequency': 16},
#  {'zi': '斤', 'n_frequency': 23},
#  {'zi': '方', 'n_frequency': 27},
#  {'zi': '无', 'n_frequency': 3},
#  {'zi': '日', 'n_frequency': 125},
#  {'zi': '曰', 'n_frequency': 14},
#  {'zi': '月', 'n_frequency': 154},
#  {'zi': '木', 'n_frequency': 324},
#  {'zi': '欠', 'n_frequency': 42},
#  {'zi': '止', 'n_frequency': 21},
#  {'zi': '歹', 'n_frequency': 17},
#  {'zi': '毋', 'n_frequency': 1},
#  {'zi': '比', 'n_frequency': 16},
#  {'zi': '毛', 'n_frequency': 22},
#  {'zi': '氏', 'n_frequency': 8},
#  {'zi': '气', 'n_frequency': 24},
#  {'zi': '水', 'n_frequency': 20},
#  {'zi': '火', 'n_frequency': 85},
#  {'zi': '爪', 'n_frequency': 3},
#  {'zi': '父', 'n_frequency': 5},
#  {'zi': '片', 'n_frequency': 6},
#  {'zi': '牙', 'n_frequency': 9},
#  {'zi': '牛', 'n_frequency': 11},
#  {'zi': '犬', 'n_frequency': 22},
#  {'zi': '王', 'n_frequency': 113},
#  {'zi': '瓦', 'n_frequency': 16},
#  {'zi': '见', 'n_frequency': 10},
#  {'zi': '贝', 'n_frequency': 59},
#  {'zi': '车', 'n_frequency': 53},
#  {'zi': '长', 'n_frequency': 5},
#  {'zi': '韦', 'n_frequency': 8},
#  {'zi': '风', 'n_frequency': 5},
#  {'zi': '乍', 'n_frequency': 13},
#  {'zi': '刍', 'n_frequency': 6},
#  {'zi': '戋', 'n_frequency': 8},
#  {'zi': '氺', 'n_frequency': 0},
#  {'zi': '疋', 'n_frequency': 7},
#  {'zi': '𤴔', 'n_frequency': 0},
#  {'zi': '疒', 'n_frequency': 74},
#  {'zi': '癶', 'n_frequency': 2},
#  {'zi': '罒', 'n_frequency': 34},
#  {'zi': '衤', 'n_frequency': 52},
#  {'zi': '钅', 'n_frequency': 88},
#  {'zi': '且', 'n_frequency': 24},
#  {'zi': '丘', 'n_frequency': 5},
#  {'zi': '丙', 'n_frequency': 6},
#  {'zi': '业', 'n_frequency': 5},
#  {'zi': '东', 'n_frequency': 6},
#  {'zi': '乎', 'n_frequency': 1},
#  {'zi': '乐', 'n_frequency': 2},
#  {'zi': '令', 'n_frequency': 21},
#  {'zi': '兄', 'n_frequency': 5},
#  {'zi': '兰', 'n_frequency': 3},
#  {'zi': '冬', 'n_frequency': 4},
#  {'zi': '出', 'n_frequency': 8},
#  {'zi': '击', 'n_frequency': 1},
#  {'zi': '包', 'n_frequency': 15},
#  {'zi': '北', 'n_frequency': 7},
#  {'zi': '半', 'n_frequency': 11},
#  {'zi': '占', 'n_frequency': 21},
#  {'zi': '卡', 'n_frequency': 0},
#  {'zi': '去', 'n_frequency': 11},
#  {'zi': '古', 'n_frequency': 19},
#  {'zi': '句', 'n_frequency': 19},
#  {'zi': '另', 'n_frequency': 2},
#  {'zi': '只', 'n_frequency': 10},
#  {'zi': '可', 'n_frequency': 17},
#  {'zi': '台', 'n_frequency': 17},
#  {'zi': '四', 'n_frequency': 3},
#  {'zi': '央', 'n_frequency': 11},
#  {'zi': '失', 'n_frequency': 14},
#  {'zi': '头', 'n_frequency': 2},
#  {'zi': '宁', 'n_frequency': 5},
#  {'zi': '它', 'n_frequency': 8},
#  {'zi': '尼', 'n_frequency': 7},
#  {'zi': '市', 'n_frequency': 2},
#  {'zi': '布', 'n_frequency': 2},
#  {'zi': '平', 'n_frequency': 9},
#  {'zi': '必', 'n_frequency': 15},
#  {'zi': '斥', 'n_frequency': 2},
#  {'zi': '旦', 'n_frequency': 17},
#  {'zi': '未', 'n_frequency': 10},
#  {'zi': '末', 'n_frequency': 5},
#  {'zi': '本', 'n_frequency': 2},
#  {'zi': '术', 'n_frequency': 4},
#  {'zi': '正', 'n_frequency': 9},
#  {'zi': '母', 'n_frequency': 6},
#  {'zi': '玄', 'n_frequency': 7},
#  {'zi': '玉', 'n_frequency': 5},
#  {'zi': '瓜', 'n_frequency': 12},
#  {'zi': '甘', 'n_frequency': 12},
#  {'zi': '生', 'n_frequency': 11},
#  {'zi': '用', 'n_frequency': 5},
#  {'zi': '田', 'n_frequency': 51},
#  {'zi': '由', 'n_frequency': 21},
#  {'zi': '甲', 'n_frequency': 10},
#  {'zi': '申', 'n_frequency': 9},
#  {'zi': '电', 'n_frequency': 3},
#  {'zi': '白', 'n_frequency': 32},
#  {'zi': '皮', 'n_frequency': 17},
#  {'zi': '皿', 'n_frequency': 30},
#  {'zi': '目', 'n_frequency': 79},
#  {'zi': '矛', 'n_frequency': 8},
#  {'zi': '矢', 'n_frequency': 16},
#  {'zi': '石', 'n_frequency': 71},
#  {'zi': '示', 'n_frequency': 13},
#  {'zi': '禾', 'n_frequency': 78},
#  {'zi': '穴', 'n_frequency': 41},
#  {'zi': '立', 'n_frequency': 34},
#  {'zi': '鸟', 'n_frequency': 62},
#  {'zi': '龙', 'n_frequency': 10},
#  {'zi': '囟', 'n_frequency': 2},
#  {'zi': '尧', 'n_frequency': 9},
#  {'zi': '屰', 'n_frequency': 3},
#  {'zi': '⺮', 'n_frequency': 108},
#  {'zi': '⺶', 'n_frequency': 0},
#  {'zi': '⺷', 'n_frequency': 1},
#  {'zi': '聿', 'n_frequency': 5},
#  {'zi': '艮', 'n_frequency': 19},
#  {'zi': '虍', 'n_frequency': 12},
#  {'zi': '覀', 'n_frequency': 7},
#  {'zi': '交', 'n_frequency': 19},
#  {'zi': '共', 'n_frequency': 15},
#  {'zi': '各', 'n_frequency': 20},
#  {'zi': '合', 'n_frequency': 18},
#  {'zi': '吉', 'n_frequency': 14},
#  {'zi': '向', 'n_frequency': 3},
#  {'zi': '吕', 'n_frequency': 4},
#  {'zi': '寺', 'n_frequency': 11},
#  {'zi': '并', 'n_frequency': 6},
#  {'zi': '庄', 'n_frequency': 3},
#  {'zi': '式', 'n_frequency': 2},
#  {'zi': '曲', 'n_frequency': 1},
#  {'zi': '竹', 'n_frequency': 1},
#  {'zi': '米', 'n_frequency': 51},
#  {'zi': '糸', 'n_frequency': 32},
#  {'zi': '缶', 'n_frequency': 16},
#  {'zi': '网', 'n_frequency': 2},
#  {'zi': '羊', 'n_frequency': 37},
#  {'zi': '羽', 'n_frequency': 42},
#  {'zi': '老', 'n_frequency': 2},
#  {'zi': '而', 'n_frequency': 11},
#  {'zi': '耒', 'n_frequency': 7},
#  {'zi': '耳', 'n_frequency': 31},
#  {'zi': '肉', 'n_frequency': 3},
#  {'zi': '臣', 'n_frequency': 6},
#  {'zi': '自', 'n_frequency': 9},
#  {'zi': '至', 'n_frequency': 12},
#  {'zi': '臼', 'n_frequency': 10},
#  {'zi': '舌', 'n_frequency': 19},
#  {'zi': '舟', 'n_frequency': 18},
#  {'zi': '色', 'n_frequency': 3},
#  {'zi': '虫', 'n_frequency': 132},
#  {'zi': '血', 'n_frequency': 6},
#  {'zi': '行', 'n_frequency': 12},
#  {'zi': '衣', 'n_frequency': 25},
#  {'zi': '西', 'n_frequency': 6},
#  {'zi': '页', 'n_frequency': 44},
#  {'zi': '齐', 'n_frequency': 5},
#  {'zi': '㐬', 'n_frequency': 4},
#  {'zi': '佥', 'n_frequency': 10},
#  {'zi': '呙', 'n_frequency': 5},
#  {'zi': '坙', 'n_frequency': 8},
#  {'zi': '夆', 'n_frequency': 4},
#  {'zi': '奂', 'n_frequency': 5},
#  {'zi': '孚', 'n_frequency': 9},
#  {'zi': '肙', 'n_frequency': 12},
#  {'zi': '豕', 'n_frequency': 15},
#  {'zi': '豸', 'n_frequency': 10},
#  {'zi': '酉', 'n_frequency': 46},
#  {'zi': '卤', 'n_frequency': 0},
#  {'zi': '员', 'n_frequency': 4},
#  {'zi': '㕻', 'n_frequency': 0},
#  {'zi': '甫', 'n_frequency': 23},
#  {'zi': '舛', 'n_frequency': 2},
#  {'zi': '良', 'n_frequency': 13},
#  {'zi': '角', 'n_frequency': 17},
#  {'zi': '言', 'n_frequency': 36},
#  {'zi': '谷', 'n_frequency': 9},
#  {'zi': '豆', 'n_frequency': 11},
#  {'zi': '赤', 'n_frequency': 7},
#  {'zi': '走', 'n_frequency': 23},
#  {'zi': '足', 'n_frequency': 76},
#  {'zi': '身', 'n_frequency': 5},
#  {'zi': '辛', 'n_frequency': 18},
#  {'zi': '辰', 'n_frequency': 9},
#  {'zi': '邑', 'n_frequency': 8},
#  {'zi': '釆', 'n_frequency': 2},
#  {'zi': '里', 'n_frequency': 13},
#  {'zi': '麦', 'n_frequency': 1},
#  {'zi': '龟', 'n_frequency': 0},
#  {'zi': '龺', 'n_frequency': 1},
#  {'zi': '幷', 'n_frequency': 3},
#  {'zi': '隹', 'n_frequency': 53},
#  {'zi': '黾', 'n_frequency': 2},
#  {'zi': '其', 'n_frequency': 17},
#  {'zi': '奉', 'n_frequency': 5},
#  {'zi': '尚', 'n_frequency': 15},
#  {'zi': '易', 'n_frequency': 15},
#  {'zi': '東', 'n_frequency': 1},
#  {'zi': '责', 'n_frequency': 2},
#  {'zi': '金', 'n_frequency': 18},
#  {'zi': '阜', 'n_frequency': 1},
#  {'zi': '隶', 'n_frequency': 3},
#  {'zi': '雨', 'n_frequency': 28},
#  {'zi': '青', 'n_frequency': 15},
#  {'zi': '非', 'n_frequency': 30},
#  {'zi': '鱼', 'n_frequency': 23},
#  {'zi': '齿', 'n_frequency': 7},
#  {'zi': '畐', 'n_frequency': 11},
#  {'zi': '咸', 'n_frequency': 8},
#  {'zi': '柬', 'n_frequency': 3},
#  {'zi': '畏', 'n_frequency': 7},
#  {'zi': '禺 ', 'n_frequency': 0},
#  {'zi': '面', 'n_frequency': 5},
#  {'zi': '革', 'n_frequency': 34},
#  {'zi': '韭', 'n_frequency': 1},
#  {'zi': '音', 'n_frequency': 12},
#  {'zi': '食', 'n_frequency': 9},
#  {'zi': '首', 'n_frequency': 2},
#  {'zi': '香', 'n_frequency': 2},
#  {'zi': '骨', 'n_frequency': 16},
#  {'zi': '鬼', 'n_frequency': 24},
#  {'zi': '高', 'n_frequency': 15},
#  {'zi': '鬥', 'n_frequency': 1},
#  {'zi': '麻', 'n_frequency': 10},
#  {'zi': '黍', 'n_frequency': 1},
#  {'zi': '黄', 'n_frequency': 0},
#  {'zi': '黑', 'n_frequency': 23},
#  {'zi': '鼓', 'n_frequency': 3},
#  {'zi': '鼻', 'n_frequency': 3},
#  {'zi': '鹿', 'n_frequency': 15}]

# %% [raw]
#         sql_stmt = f"""
#             update t_zi
#             set set_id = 30
#                 where zi='{x}' and (set_id is null or set_id = '' or set_id > 30)
#             ;
#         """

# %%
df_freq = create_df_from_list(data_freq)

# %%
df_freq
# Out:
#     zi  n_frequency
# 0    丨           25
# 1    丶           26
# 2    丿           40
# 3    乀            3
# 4    乁            1
# ..  ..          ...
# 417  黄            0
# 418  黑           23
# 419  鼓            3
# 420  鼻            3
# 421  鹿           15
#
# [422 rows x 2 columns]

# %%
df.head()
# Out:
#   zi  is_zi id_kangxi meaning     pinyin  n_strokes term examples variant
# 0  丨      0       2.0    line  gùn / gǔn          1       十、中、串、丰
# 1  丶      0       3.0     dot        zhǔ          1  丶字旁  丸、凡、丹、户
# 2  丿      0             slash        piě          1       乂、乃、久、八
# 3  乀      0             slash        piě          1       乂、乃、久、八
# 4  乁      0             slash        piě          1

# %%
df = merge_zi_dataframes(df, df_freq)
df.head(10)
# Out:
#   zi  is_zi id_kangxi meaning     pinyin  n_strokes term examples  \
# 0  丨      0       2.0    line  gùn / gǔn          1       十、中、串、丰
# 1  丶      0       3.0     dot        zhǔ          1  丶字旁  丸、凡、丹、户
# 2  丿      0             slash        piě          1       乂、乃、久、八
# 3  乀      0             slash        piě          1       乂、乃、久、八
# 4  乁      0             slash        piě          1
# 5  乚      0            second         yǐ          1         九、乞、也
# 6  乛      0            second         yǐ          1         九、乞、也
# 7  亅      0       6.0    hook  gōu / jué          1         了、矛、事
# 8  一      1       1.0     one         yī          1  一字旁  王、丁、七、三
# 9  乙      1            second         yǐ          1         九、乞、也
#
#                variant  n_frequency
# 0                                25
# 1                                26
# 2                                40
# 3                                 3
# 4                                 1
# 5                                 9
# 6                                 3
# 7                                 1
# 8  丶 丨 亅 丿 乀 ⺄ 乁 乙 乚 乛           73
# 9                                11

# %%
with DBConn() as _conn:
    df.to_sql("t_ele_zi", _conn, if_exists="replace", index=False)

# %% [markdown]
# ### merge category

# %%
with DBConn() as _conn:
    sql_2 = f""" 
        select 
            p.zi, p.category, p.sub_category
        from t_part p
        where trim(p.category || '') != ''
;        
        
    """
    df_2 = pd.read_sql(sql_2, _conn).fillna("")

# %%
df_2
# Out:
#     zi category sub_category
# 0    ⺌      概念-
# 1    ⺍      概念-
# 2    氺     天文-水
# 3    𤴔     人-生理
# 4    罓      社会-         tool
# ..  ..      ...          ...
# 385  ⺁  radical
# 386  龺  radical
# 387  毋      概念-
# 388  ⺪     人-生理
# 389  ⺩  radical
#
# [390 rows x 3 columns]

# %%
df = merge_zi_dataframes(df, df_2)
df.head(10)
# Out:
#   zi  is_zi id_kangxi meaning     pinyin  n_strokes term examples  \
# 0  丨      0       2.0    line  gùn / gǔn          1       十、中、串、丰
# 1  丶      0       3.0     dot        zhǔ          1  丶字旁  丸、凡、丹、户
# 2  丿      0             slash        piě          1       乂、乃、久、八
# 3  乀      0             slash        piě          1       乂、乃、久、八
# 4  乁      0             slash        piě          1
# 5  乚      0            second         yǐ          1         九、乞、也
# 6  乛      0            second         yǐ          1         九、乞、也
# 7  亅      0       6.0    hook  gōu / jué          1         了、矛、事
# 8  一      1       1.0     one         yī          1  一字旁  王、丁、七、三
# 9  乙      1            second         yǐ          1         九、乞、也
#
#                variant  n_frequency category sub_category
# 0                                25  radical
# 1                                26  radical
# 2                                40  radical
# 3                                 3  radical
# 4                                 1  radical
# 5                                 9  radical
# 6                                 3  radical
# 7                                 1  radical
# 8  丶 丨 亅 丿 乀 ⺄ 乁 乙 乚 乛           73    数理-计算       number
# 9                                11    数理-天干

# %%
df.to_csv("elemental_zi_v4.csv", index=False)

# %%
with DBConn() as _conn:
    df["notes"] = ""
    df.to_sql("t_ele_zi", _conn, if_exists="replace", index=False)

# %% [markdown]
# #### convert id_kangxi to int, trim(meaning)

# %%
with DBConn() as _conn:
    sql_stmt = f"""
        update t_ele_zi 
        set id_kangxi = cast(id_kangxi as INT),
            meaning = trim(meaning),
            n_frequency = cast(n_frequency as INT)
        ;
    """
    db_run_sql(sql_stmt, _conn, debug=False)

# %%
with DBConn() as _conn:
    sql_2 = f""" 
        select 
            n_strokes, zi
        from t_ele_zi
        order by n_strokes, zi
;        
        
    """
    df_2 = pd.read_sql(sql_2, _conn).fillna("")

# %%
df_2
# Out:
#      n_strokes zi
# 0            1  一
# 1            1  丨
# 2            1  丶
# 3            1  丿
# 4            1  乀
# ..         ... ..
# 417         12  黄
# 418         12  黍
# 419         12  黑
# 420         13  鼓
# 421         14  鼻
#
# [422 rows x 2 columns]

# %% [markdown]
# ### get zi_part columns

# %%
s = """
		  case when zi_left_up = '{x}' then 1 else 0 end as n_left_up
		, case when zi_left = '{x}' then 1 else 0 end as n_left
		, case when zi_left_down = '{x}' then 1 else 0 end as n_left_down
		, case when zi_up = '{x}' then 1 else 0 end as n_up
		, case when zi_mid = '{x}' then 1 else 0 end as n_mid
		, case when zi_down = '{x}' then 1 else 0 end as n_down
		, case when zi_right_up = '{x}' then 1 else 0 end as n_right_up
		, case when zi_right = '{x}' then 1 else 0 end as n_right
		, case when zi_right_down = '{x}' then 1 else 0 end as n_right_down
		, case when zi_mid_in = '{x}' then 1 else 0 end as n_mid_in
		, case when zi_mid_out = '{x}' then 1 else 0 end as n_mid_out

"""

cols = []
for i in s.split("\n"):
#     print(i)
    if not i.strip(): continue
    j = i.split("=")
#     print(j[0])
    x = j[0].replace(",", "").replace("case when", "").strip()
    cols.append(x)

cols
# Out:
# ['zi_left_up',
#  'zi_left',
#  'zi_left_down',
#  'zi_up',
#  'zi_mid',
#  'zi_down',
#  'zi_right_up',
#  'zi_right',
#  'zi_right_down',
#  'zi_mid_in',
#  'zi_mid_out']

# %%
" is not null or  ".join(cols)
# Out:
# 'zi_left_up is not null or  zi_left is not null or  zi_left_down is not null or  zi_up is not null or  zi_mid is not null or  zi_down is not null or  zi_right_up is not null or  zi_right is not null or  zi_right_down is not null or  zi_mid_in is not null or  zi_mid_out'

# %% [raw]
# with DBConn() as _conn:
#     for x in zi_30:
#
#         # f x != char1: continue
#
#         sql_stmt = f"""
#             update t_zi
#             set set_id = 30
#                 where zi='{x}' and (set_id is null or set_id = '' or set_id > 30)
#             ;
#         """
#         db_run_sql(sql_stmt, _conn, debug=False)  #  ) #
