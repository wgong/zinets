# %% [markdown]
# The following Zi failed
# ```
# 儿 猴 龙 头 死 毛 皮 眉 耳 肉 一 午 四 寅 甲 癸 零 丿 彡 攵 氵犭
# ```

# %%
from time import time
from datetime import datetime
import re
from pathlib import Path

import pandas as pd 

import ollama

from utils import *

# %%
model_name = "qwen2.5"  # "llama3.1"
pattern = r'```json\s*(.*?)\s*```'
file_log = "char360-qwen2.5.log"
lang = "ENU"

prompt_zi = LLM_PROMPT_ZI_DICT[lang]

# %%
prompt_zi = """
You are an expert in Chinese language, 

can you generate a holistic view on this chinese character  {zi}
in terms of the following attributes:
含义
字形
读音 
字源
常用词组
成语
例句
短故事
诗词
图片
音频 
视频 
电影
参考资料
有趣网站

(1) give the answer in Chinese 
(2) format the answer in valid json and ensure quotes are properly escaped (specifically avoid double-quotes nested in doube-quotes)
(3) whenever possible, give 5 or more examples for the following attributes:

常用词组
成语
例句
短故事
诗词
图片
音频 
视频 
电影
参考资料
有趣网站

"""

# %% [raw]
# zi = '气'

# %%
df = pd.read_csv("char360_fib_num.csv")
zi_fib_nums = df.to_dict("records")

# %% [raw]
# prompt_zi.format(zi=zi)

# %% [raw]
# fib_num = 100
# str(fib_num).zfill(4)

# %% [raw]
# # Example usage:
# # log_msg("This is a test message")
# log_msg("[ERROR] No JSON extracted: 犭", "char360-qwen2.5.log")

# %%
for xx in zi_fib_nums:
    zi, fib_num = xx['zi'], xx['fib_num']
    fib_num_str = str(fib_num).zfill(4)
    fp = Path(f"./llm_models/{model_name}") / f"{fib_num_str}-{zi}-1.json"    
    if fp.exists():
        # log_msg(f"SKIP {zi}: Already processed - {fp} ", file_log)
        continue

    print(f"Processing {zi} ...")
    
    ts_now = datetime.now()   
    ts_1 = time()
    try:
        resp = ollama.generate(model=model_name, prompt=prompt_zi.format(zi=zi))
    except Exception as e:
        log_msg(f"[ERROR] {zi} : Failed to call ollama.generate()", file_log)
        continue
        
    ts_2 = time()
    del_t = ts_2 - ts_1
    del_t_str = f"{del_t:.3f}"
    json_raw = resp.get('response', "")
    if not json_raw: 
        log_msg(f"[ERROR] No LLM response: {zi}", file_log)
        continue

    log_msg(f"[{str(ts_now)}] Completed {zi} in {del_t_str} sec")

    match = re.search(pattern, json_raw, re.DOTALL)

    if match:
        json_string = match.group(1)
        if not json_string:
            log_msg(f"[WARN] No JSON extracted: {zi}")
            continue
            
        with open(fp, "w", encoding="utf-8") as f:
            f.write(json_string)
    else:
        log_msg(f"[ERROR] No JSON extracted: {zi}", file_log)
# Out:
# Processing 杉 ...
# [2024-09-20 20:51:15.462352] Completed 杉 in 123.596 sec
# [ERROR] No JSON extracted: 杉
# Processing 来 ...
# [2024-09-20 20:53:19.059996] Completed 来 in 148.386 sec
# Processing 林 ...
# [2024-09-20 20:55:47.447408] Completed 林 in 116.707 sec
# [ERROR] No JSON extracted: 林
# Processing 比 ...
# [2024-09-20 20:57:44.154971] Completed 比 in 116.075 sec
# Processing 自 ...
# [2024-09-20 20:59:40.231434] Completed 自 in 97.378 sec
# Processing 舟 ...
# [2024-09-20 21:01:17.610142] Completed 舟 in 189.588 sec
# Processing 远 ...
# [2024-09-20 21:04:27.199852] Completed 远 in 108.610 sec
# Processing 采 ...
# [2024-09-20 21:06:15.811059] Completed 采 in 120.348 sec
# Processing 兑 ...
# [2024-09-20 21:08:16.159908] Completed 兑 in 148.806 sec
# Processing 军 ...
# [2024-09-20 21:10:44.967709] Completed 军 in 72.402 sec
# Processing 减 ...
# [2024-09-20 21:11:57.370733] Completed 减 in 118.451 sec
# Processing 前 ...
# [2024-09-20 21:13:55.823143] Completed 前 in 70.787 sec
# Processing 卖 ...
# [2024-09-20 21:15:06.610729] Completed 卖 in 144.579 sec
# Processing 君 ...
# [2024-09-20 21:17:31.191145] Completed 君 in 110.958 sec
# Processing 商 ...
# [2024-09-20 21:19:22.150173] Completed 商 in 163.228 sec
# Processing 器 ...
# [2024-09-20 21:22:05.379464] Completed 器 in 155.139 sec
# Processing 国 ...
# [2024-09-20 21:24:40.519316] Completed 国 in 143.907 sec
# Processing 声 ...
# [2024-09-20 21:27:04.426775] Completed 声 in 111.539 sec
# [ERROR] No JSON extracted: 声
# Processing 奇 ...
# [2024-09-20 21:28:55.967099] Completed 奇 in 111.723 sec
# Processing 妹 ...
# [2024-09-20 21:30:47.689992] Completed 妹 in 164.516 sec
# Processing 姐 ...
# [2024-09-20 21:33:32.206961] Completed 姐 in 130.703 sec
# Processing 存 ...
# [2024-09-20 21:35:42.911295] Completed 存 in 80.662 sec
# Processing 宇 ...
# [2024-09-20 21:37:03.573457] Completed 宇 in 99.948 sec
# Processing 宙 ...
# [2024-09-20 21:38:43.522733] Completed 宙 in 58.905 sec
# Processing 寻 ...
# [2024-09-20 21:39:42.428297] Completed 寻 in 88.841 sec
# Processing 将 ...
# [2024-09-20 21:41:11.270392] Completed 将 in 140.495 sec
# Processing 尽 ...
# [2024-09-20 21:43:31.767125] Completed 尽 in 80.661 sec
# [ERROR] No JSON extracted: 尽
# Processing 弗 ...
# [2024-09-20 21:44:52.428740] Completed 弗 in 95.965 sec
# Processing 弱 ...
# [2024-09-20 21:46:28.395074] Completed 弱 in 81.633 sec
# Processing 强 ...
# [2024-09-20 21:47:50.028436] Completed 强 in 142.972 sec
# Processing 情 ...
# [2024-09-20 21:50:13.000684] Completed 情 in 77.585 sec
# Processing 数 ...
# [2024-09-20 21:51:30.586629] Completed 数 in 85.645 sec
# [ERROR] No JSON extracted: 数
# Processing 易 ...
# [2024-09-20 21:52:56.232188] Completed 易 in 150.521 sec
# Processing 晓 ...
# [2024-09-20 21:55:26.755089] Completed 晓 in 138.471 sec
# [ERROR] No JSON extracted: 晓
# Processing 柳 ...
# [2024-09-20 21:57:45.226225] Completed 柳 in 111.559 sec
# [ERROR] No JSON extracted: 柳
# Processing 树 ...
# [2024-09-20 21:59:36.786754] Completed 树 in 116.115 sec
# Processing 根 ...
# [2024-09-20 22:01:32.903164] Completed 根 in 117.237 sec
# Processing 每 ...
# [2024-09-20 22:03:30.140303] Completed 每 in 86.481 sec
# Processing 润 ...
# [2024-09-20 22:04:56.622989] Completed 润 in 120.767 sec
# Processing 灵 ...
# [2024-09-20 22:06:57.390435] Completed 灵 in 135.419 sec
# [ERROR] No JSON extracted: 灵
# Processing 热 ...
# [2024-09-20 22:09:12.811064] Completed 热 in 219.225 sec
# Processing 画 ...
# [2024-09-20 22:12:52.036162] Completed 画 in 117.273 sec
# Processing 省 ...
# [2024-09-20 22:14:49.310770] Completed 省 in 93.187 sec
# Processing 矛 ...
# [2024-09-20 22:16:22.498738] Completed 矛 in 113.695 sec
# [ERROR] No JSON extracted: 矛
# Processing 矣 ...
# [2024-09-20 22:18:16.193841] Completed 矣 in 70.619 sec
# Processing 短 ...
# [2024-09-20 22:19:26.814381] Completed 短 in 109.834 sec
# Processing 神 ...
# [2024-09-20 22:21:16.648931] Completed 神 in 138.069 sec
# Processing 禽 ...
# [2024-09-20 22:23:34.719248] Completed 禽 in 80.689 sec
# Processing 章 ...
# [2024-09-20 22:24:55.408360] Completed 章 in 86.221 sec
# Processing 算 ...
# [2024-09-20 22:26:21.630040] Completed 算 in 205.236 sec
# Processing 紫 ...
# [2024-09-20 22:29:46.868065] Completed 紫 in 190.474 sec
# Processing 缶 ...
# [2024-09-20 22:32:57.342859] Completed 缶 in 92.075 sec
# Processing 老 ...
# [2024-09-20 22:34:29.418666] Completed 老 in 296.807 sec
# Processing 者 ...

# %% [raw]
# response = ollama.chat(model=model_name, messages=[
#   {
#     'role': 'user',
#     'content': prompt_zi.format(zi=zi),
#   },
# ])
# print(response['message']['content'])

# %% [raw]
# json_raw = """```json
# {
#     "汉字": "气",
#     "含义": "1. 氧气, 空气 2. 能量, 力量 3. 性情, 心态 4. 名声, 声望 5. 气息",
#     "字形": "由三部分组成，上面是'云', 中间是一个'又', 下面是'口'",
#     "读音": "qi4",
#     "字源": "象形字。甲骨文中的'气'字像一缕上升的烟雾形状。",
#     "常用词组": ["气体", "气质", "生气", "人气", "风气"],
#     "成语": ["气息奄奄", "气吞山河", "气急败坏", "气宇轩昂", "气贯长虹"],
#     "例句": ["天气转凉，出门要多穿衣服。qi4 ti4 zhuan3 liang2 ，chu1 men2 yao5 duo3 chuan1 yi1 fu4 。", "他的气质很吸引人。ta de qi4 zhi4 hen3 xiang1 jin1 ren2 。", "你别生气了，气坏身体。ni3 bei4 qi1 hai4 shen1 ti3 。"],
#     "短故事": ["从前有一座山，山上住着一位老道长。每当他修炼到极致时，就会有一股强大的力量从他的身体中涌出。这股力量就是'气'。一次，他在山顶上练功时，不小心将周围的石头都吹飞了。",
#     "一天夜里，一个年轻的小道士来找他学艺，但见山下起雾了，就问师父：‘师父，我们现在要去哪修炼呢？’老道长回答说：‘就在这里，雾就是我们的气。’小道士听后，豁然开朗，明白了师父的教诲。"],
#     "诗词": ["唐·李白《将进酒》：“君不见黄河之水天上来,奔流到海不复回. 须知一樽还一笑,人生长恨水长东.”中'一樽还一笑',这里'笑'即有精神充沛之意，也与'气'相关。"],
#     "图片": ["http://example.com/qi4_image1.jpg", "http://example.com/qi4_image2.png", "http://example.com/qi4_image3.jpeg"],
#     "音频": ["http://example.com/qi4_audio1.mp3", "http://example.com/qi4_audio2.wav", "http://example.com/qi4_audio3.aac"],
#     "视频": ["http://example.com/qi4_video1.mp4", "http://example.com/qi4_video2.webm", "http://example.com/qi4_video3.flv"],
#     "电影": ["《卧虎藏龙》", "《英雄》", "《无极》"],
#     "参考资料": ["https://www.zdic.net/hans/%E6%B0%94", "https://baike.baidu.com/item/%E6%B0%98"],
#     "有趣网站": ["http://www.cihai.com/qi4", "https://dict.cn/zi/qi"]
# }
# ```"""
