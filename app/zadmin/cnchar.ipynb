# %%
words = [ '日子',   '生日', '日光',     '日历',  '今日',   '近日',   '即日', '昨日'
    '次日',   '当日',   '多日',   '度日',   # '按日', '访日', '几日', '全日制', '日报表','日产量', '日程表', '日创',   '日方',
  '改日',   '工作日', '国庆日', '好日子', '假日',   '节日',
    
  '吉日',     '抗日',   '劳动日', '连日',   '烈日',
  '落日',   '每日',   '明日',   '平日',   '穷日子', '全日',
   '日报',   '日本',   '日产',   '日常',
   '日程',    '日出',  '日落',   '日记', 
        # '日间',
  # '日见',   '日渐',   '日均',   '日刊',    '日内',
  '日期',   # '日趋',   '日下',   '日夜',   '日益',   '日用',
  '日用品', # '日月',   '日照',   '日臻',   '日志',   '日中',
    # '时日',   '双日',   '数日',   '同日',
  '往日',   '夏日',   '星期日', '昔日',   '翌日',  #  '一日',
  '整日',   '值日',   '终日',   '中日',   '逐日',   
    # '日工资',
]

idioms = [
    '日出不穷', '日出而作','日入而息', '日复一日', '日积月累','日久见人心', '日久天长', 
    '日理万机',  '风和日丽', '日落千丈','日日夜夜', '日新月异',    '日夜兼程',  '日以继夜', '日以为常', '烈日炎炎',
    '一日三餐', '旭日东升',
  # '日薄桑榆',            '日薄虞渊', '日不我与',           '日不暇给', '日不移晷',
#   '日不移影',            '日长一线',
#   '日程月课',           
#   '日出三竿',           '日东月西', '日短心长',
#   '日锻月炼',            '日旰不食',
#   '日旰忘餐',           '日旰忘食', '日高三丈',
#   '日和风暖',           '日积月聚', 
#   '日计不足，岁计有余', '日渐月染', '日角龙庭',
#   '日角龙颜',           '日角偃月', '日角珠庭',
#   '日近长安远',         '日进斗金', 
#   '日久年深',           '日久岁长', '日久岁深',
#           '日久月深', '日就月将',
#   '日居月诸',           '日来月往', '日累月积',
#             '日丽风清',
#   '日陵月替',            '日落西山',
#   '日迈月征',           '日莫途远', '日暮道远',
#   '日暮路远',           '日暮途穷', '日暮途远',
#   '日暖风和',           '日暖风恬', '日乾夕惕',
#   '日杒月减',           '日杒月削', 
#   '日濡月染',           '日上三竿', '日甚一日',
#   '日慎一日',           '日升月恒', '日省月课',
#   '日省月试',           '日省月修', '日食万钱',
#   '日试万言',           '日诵五车', '日往月来',
#   '日无暇晷',           '日下无双', '日削月割',
#   '日削月杒',           '日销月铄', '日新月盛',
#        '日新月著', '日行千里',
#   '日许多时',           '日许时间', 
#   '日已三竿',           
#   '日异月更',           '日异月殊', '日异月新',
#   '日益月滋',           '日堙月塞', '日引月长',
#   '日饮亡何',           '日饮无何', '日有万机',
#   '日月不居',           '日月参辰', '日月蹉跎',
#   '日月合壁',
]

# %%
", ".join(words)
# Out:
# '日子, 生日, 日光, 日历, 今日, 近日, 即日, 昨日次日, 当日, 多日, 度日, 改日, 工作日, 国庆日, 好日子, 假日, 节日, 吉日, 抗日, 劳动日, 连日, 烈日, 落日, 每日, 明日, 平日, 穷日子, 全日, 日报, 日本, 日产, 日常, 日程, 日出, 日落, 日记, 日期, 日用品, 往日, 夏日, 星期日, 昔日, 翌日, 整日, 值日, 终日, 中日, 逐日'

# %%
", ".join(idioms)
# Out:
# '日出不穷, 日出而作, 日入而息, 日复一日, 日积月累, 日久见人心, 日久天长, 日理万机, 风和日丽, 日落千丈, 日日夜夜, 日新月异, 日夜兼程, 日以继夜, 日以为常, 烈日炎炎, 一日三餐, 旭日东升'
